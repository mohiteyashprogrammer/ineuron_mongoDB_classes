# %%
from pprint import pprint
import pandas as pd
import seaborn as sns
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer 
print(db)
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
data = sns.load_dataset("titanic")

# %%
db = client["titanic"]

# %%
collection = db["record"]

# %%
data = data.to_dict(orient="record")
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_13244\2704615251.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data = data.to_dict(orient="record")

# %%
collection.insert_many(data)

# %%
for i in collection.find():
    pprint(i)
# Out:
# {'_id': ObjectId('63e7ada1fe31db2740c6a28c'),
#  'adult_male': True,
#  'age': 22.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.25,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a28d'),
#  'adult_male': False,
#  'age': 38.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 71.2833,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a28e'),
#  'adult_male': False,
#  'age': 26.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.925,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a28f'),
#  'adult_male': False,
#  'age': 35.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 53.1,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a290'),
#  'adult_male': True,
#  'age': 35.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a291'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 8.4583,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a292'),
#  'adult_male': True,
#  'age': 54.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': 'E',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 51.8625,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a293'),
#  'adult_male': False,
#  'age': 2.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 21.075,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 3,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a294'),
#  'adult_male': False,
#  'age': 27.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 11.1333,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a295'),
#  'adult_male': False,
#  'age': 14.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 30.0708,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a296'),
#  'adult_male': False,
#  'age': 4.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': 'G',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 16.7,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a297'),
#  'adult_male': False,
#  'age': 58.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.55,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a298'),
#  'adult_male': True,
#  'age': 20.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a299'),
#  'adult_male': True,
#  'age': 39.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 31.275,
#  'parch': 5,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a29a'),
#  'adult_male': False,
#  'age': 14.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8542,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a29b'),
#  'adult_male': False,
#  'age': 55.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 16.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a29c'),
#  'adult_male': False,
#  'age': 2.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 29.125,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 4,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a29d'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a29e'),
#  'adult_male': False,
#  'age': 31.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 18.0,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a29f'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.225,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a0'),
#  'adult_male': True,
#  'age': 35.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a1'),
#  'adult_male': True,
#  'age': 34.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a2'),
#  'adult_male': False,
#  'age': 15.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 8.0292,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a3'),
#  'adult_male': True,
#  'age': 28.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'A',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 35.5,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a4'),
#  'adult_male': False,
#  'age': 8.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 21.075,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 3,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a5'),
#  'adult_male': False,
#  'age': 38.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 31.3875,
#  'parch': 5,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a6'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.225,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a7'),
#  'adult_male': True,
#  'age': 19.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 263.0,
#  'parch': 2,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 3,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a8'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.8792,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2a9'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2aa'),
#  'adult_male': True,
#  'age': 40.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 27.7208,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ab'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 146.5208,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ac'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ad'),
#  'adult_male': True,
#  'age': 66.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ae'),
#  'adult_male': True,
#  'age': 28.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 82.1708,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2af'),
#  'adult_male': True,
#  'age': 42.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 52.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b0'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.2292,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b1'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b2'),
#  'adult_male': False,
#  'age': 18.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 18.0,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b3'),
#  'adult_male': False,
#  'age': 14.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 11.2417,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b4'),
#  'adult_male': False,
#  'age': 40.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.475,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b5'),
#  'adult_male': False,
#  'age': 27.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 21.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b6'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b7'),
#  'adult_male': False,
#  'age': 3.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 41.5792,
#  'parch': 2,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b8'),
#  'adult_male': False,
#  'age': 19.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.8792,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2b9'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ba'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 15.5,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2bb'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2bc'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 21.6792,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2bd'),
#  'adult_male': False,
#  'age': 18.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 17.8,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2be'),
#  'adult_male': False,
#  'age': 7.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 39.6875,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 4,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2bf'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c0'),
#  'adult_male': False,
#  'age': 49.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 76.7292,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c1'),
#  'adult_male': False,
#  'age': 29.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c2'),
#  'adult_male': True,
#  'age': 65.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 61.9792,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c3'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 35.5,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c4'),
#  'adult_male': False,
#  'age': 21.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c5'),
#  'adult_male': True,
#  'age': 28.5,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.2292,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c6'),
#  'adult_male': False,
#  'age': 5.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 27.75,
#  'parch': 2,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c7'),
#  'adult_male': False,
#  'age': 11.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 46.9,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 5,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c8'),
#  'adult_male': True,
#  'age': 22.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.2292,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2c9'),
#  'adult_male': False,
#  'age': 38.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': nan,
#  'embarked': nan,
#  'fare': 80.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ca'),
#  'adult_male': True,
#  'age': 45.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 83.475,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2cb'),
#  'adult_male': False,
#  'age': 4.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 27.9,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 3,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2cc'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 27.7208,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2cd'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 15.2458,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ce'),
#  'adult_male': False,
#  'age': 29.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': 'F',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2cf'),
#  'adult_male': True,
#  'age': 19.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.1583,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d0'),
#  'adult_male': False,
#  'age': 17.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.925,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 4,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d1'),
#  'adult_male': True,
#  'age': 26.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.6625,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d2'),
#  'adult_male': True,
#  'age': 32.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d3'),
#  'adult_male': False,
#  'age': 16.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 46.9,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 5,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d4'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 73.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d5'),
#  'adult_male': True,
#  'age': 26.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 14.4542,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d6'),
#  'adult_male': True,
#  'age': 32.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 56.4958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d7'),
#  'adult_male': True,
#  'age': 25.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': 'F',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.65,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d8'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2d9'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2da'),
#  'adult_male': False,
#  'age': 0.83,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 29.0,
#  'parch': 2,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2db'),
#  'adult_male': False,
#  'age': 30.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 12.475,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2dc'),
#  'adult_male': True,
#  'age': 22.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.0,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2dd'),
#  'adult_male': True,
#  'age': 29.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.5,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2de'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.7875,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2df'),
#  'adult_male': True,
#  'age': 28.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 47.1,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e0'),
#  'adult_male': False,
#  'age': 17.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e1'),
#  'adult_male': False,
#  'age': 33.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 15.85,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 3,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e2'),
#  'adult_male': True,
#  'age': 16.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 34.375,
#  'parch': 3,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e3'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e4'),
#  'adult_male': False,
#  'age': 23.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 263.0,
#  'parch': 2,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 3,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e5'),
#  'adult_male': True,
#  'age': 24.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e6'),
#  'adult_male': True,
#  'age': 29.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e7'),
#  'adult_male': True,
#  'age': 20.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8542,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e8'),
#  'adult_male': True,
#  'age': 46.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'E',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 61.175,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2e9'),
#  'adult_male': True,
#  'age': 26.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 20.575,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ea'),
#  'adult_male': True,
#  'age': 59.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.25,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2eb'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ec'),
#  'adult_male': True,
#  'age': 71.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': 'A',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 34.6542,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ed'),
#  'adult_male': True,
#  'age': 23.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 63.3583,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ee'),
#  'adult_male': False,
#  'age': 34.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 23.0,
#  'parch': 1,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ef'),
#  'adult_male': True,
#  'age': 34.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f0'),
#  'adult_male': False,
#  'age': 28.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f1'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f2'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 77.2875,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f3'),
#  'adult_male': True,
#  'age': 33.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.6542,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f4'),
#  'adult_male': True,
#  'age': 37.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.925,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f5'),
#  'adult_male': True,
#  'age': 28.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f6'),
#  'adult_male': False,
#  'age': 21.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.65,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f7'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.775,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f8'),
#  'adult_male': True,
#  'age': 38.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2f9'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 24.15,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2fa'),
#  'adult_male': True,
#  'age': 47.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 52.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2fb'),
#  'adult_male': False,
#  'age': 14.5,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 14.4542,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2fc'),
#  'adult_male': True,
#  'age': 22.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2fd'),
#  'adult_male': False,
#  'age': 20.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.825,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2fe'),
#  'adult_male': False,
#  'age': 17.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 14.4583,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a2ff'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.925,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a300'),
#  'adult_male': True,
#  'age': 70.5,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a301'),
#  'adult_male': True,
#  'age': 29.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 21.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a302'),
#  'adult_male': True,
#  'age': 24.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 247.5208,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a303'),
#  'adult_male': False,
#  'age': 2.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 31.275,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 4,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a304'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 73.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a305'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a306'),
#  'adult_male': True,
#  'age': 32.5,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 30.0708,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a307'),
#  'adult_male': False,
#  'age': 32.5,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': 'E',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a308'),
#  'adult_male': True,
#  'age': 54.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 77.2875,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a309'),
#  'adult_male': False,
#  'age': 12.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 11.2417,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a30a'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a30b'),
#  'adult_male': True,
#  'age': 24.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.1417,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a30c'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': 'F',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 22.3583,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a30d'),
#  'adult_male': True,
#  'age': 45.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 6.975,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a30e'),
#  'adult_male': True,
#  'age': 33.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a30f'),
#  'adult_male': True,
#  'age': 20.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a310'),
#  'adult_male': False,
#  'age': 47.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 14.5,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a311'),
#  'adult_male': False,
#  'age': 29.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a312'),
#  'adult_male': True,
#  'age': 25.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a313'),
#  'adult_male': True,
#  'age': 23.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 15.0458,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a314'),
#  'adult_male': False,
#  'age': 19.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.2833,
#  'parch': 2,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a315'),
#  'adult_male': True,
#  'age': 37.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 53.1,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a316'),
#  'adult_male': True,
#  'age': 16.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.2167,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a317'),
#  'adult_male': True,
#  'age': 24.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 79.2,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a318'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 15.2458,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a319'),
#  'adult_male': False,
#  'age': 22.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a31a'),
#  'adult_male': False,
#  'age': 24.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 15.85,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a31b'),
#  'adult_male': True,
#  'age': 19.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 6.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a31c'),
#  'adult_male': True,
#  'age': 18.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 11.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a31d'),
#  'adult_male': True,
#  'age': 19.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 36.75,
#  'parch': 1,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a31e'),
#  'adult_male': True,
#  'age': 27.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.7958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a31f'),
#  'adult_male': False,
#  'age': 9.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 34.375,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a320'),
#  'adult_male': True,
#  'age': 36.5,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': 'F',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 2,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a321'),
#  'adult_male': True,
#  'age': 42.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a322'),
#  'adult_male': True,
#  'age': 51.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 12.525,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a323'),
#  'adult_male': False,
#  'age': 22.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 66.6,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a324'),
#  'adult_male': True,
#  'age': 55.5,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a325'),
#  'adult_male': True,
#  'age': 40.5,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 14.5,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a326'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.3125,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a327'),
#  'adult_male': True,
#  'age': 51.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 61.3792,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a328'),
#  'adult_male': False,
#  'age': 16.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.7333,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a329'),
#  'adult_male': True,
#  'age': 30.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a32a'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.6625,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a32b'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 69.55,
#  'parch': 2,
#  'pclass': 3,
# ...
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d2'),
#  'adult_male': True,
#  'age': 32.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 56.4958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d3'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 29.7,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d4'),
#  'adult_male': True,
#  'age': 20.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.925,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d5'),
#  'adult_male': True,
#  'age': 16.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d6'),
#  'adult_male': False,
#  'age': 30.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 31.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d7'),
#  'adult_male': True,
#  'age': 34.5,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 6.4375,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d8'),
#  'adult_male': True,
#  'age': 17.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 8.6625,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5d9'),
#  'adult_male': True,
#  'age': 42.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.55,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5da'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 69.55,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 8,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5db'),
#  'adult_male': True,
#  'age': 35.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5dc'),
#  'adult_male': True,
#  'age': 28.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 33.0,
#  'parch': 1,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5dd'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 89.1042,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5de'),
#  'adult_male': False,
#  'age': 4.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 31.275,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 4,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5df'),
#  'adult_male': True,
#  'age': 74.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.775,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e0'),
#  'adult_male': False,
#  'age': 9.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 15.2458,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e1'),
#  'adult_male': False,
#  'age': 16.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 39.4,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e2'),
#  'adult_male': False,
#  'age': 44.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e3'),
#  'adult_male': False,
#  'age': 18.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.35,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e4'),
#  'adult_male': False,
#  'age': 45.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 164.8667,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e5'),
#  'adult_male': True,
#  'age': 51.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'E',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.55,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e6'),
#  'adult_male': False,
#  'age': 24.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 19.2583,
#  'parch': 3,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e7'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.2292,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e8'),
#  'adult_male': True,
#  'age': 41.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 14.1083,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 2,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5e9'),
#  'adult_male': True,
#  'age': 21.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 11.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5ea'),
#  'adult_male': False,
#  'age': 48.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 25.9292,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5eb'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 69.55,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 8,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5ec'),
#  'adult_male': True,
#  'age': 24.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5ed'),
#  'adult_male': False,
#  'age': 42.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5ee'),
#  'adult_male': False,
#  'age': 27.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 13.8583,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5ef'),
#  'adult_male': True,
#  'age': 31.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': 'A',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 50.4958,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f0'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.5,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f1'),
#  'adult_male': False,
#  'age': 4.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 11.1333,
#  'parch': 1,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f2'),
#  'adult_male': True,
#  'age': 26.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f3'),
#  'adult_male': False,
#  'age': 47.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'D',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 52.5542,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f4'),
#  'adult_male': True,
#  'age': 33.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 5.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f5'),
#  'adult_male': True,
#  'age': 47.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.0,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f6'),
#  'adult_male': False,
#  'age': 28.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 24.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f7'),
#  'adult_male': False,
#  'age': 15.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 7.225,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'child'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f8'),
#  'adult_male': True,
#  'age': 20.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 9.8458,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5f9'),
#  'adult_male': True,
#  'age': 19.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5fa'),
#  'adult_male': True,
#  'age': nan,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5fb'),
#  'adult_male': False,
#  'age': 56.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 83.1583,
#  'parch': 1,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5fc'),
#  'adult_male': False,
#  'age': 25.0,
#  'alive': 'yes',
#  'alone': False,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 26.0,
#  'parch': 1,
#  'pclass': 2,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5fd'),
#  'adult_male': True,
#  'age': 33.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.8958,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5fe'),
#  'adult_male': False,
#  'age': 22.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5167,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a5ff'),
#  'adult_male': True,
#  'age': 28.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 10.5,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a600'),
#  'adult_male': True,
#  'age': 25.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 7.05,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a601'),
#  'adult_male': False,
#  'age': 39.0,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 29.125,
#  'parch': 5,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a602'),
#  'adult_male': True,
#  'age': 27.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Second',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 13.0,
#  'parch': 0,
#  'pclass': 2,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a603'),
#  'adult_male': False,
#  'age': 19.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'B',
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 30.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'female',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a604'),
#  'adult_male': False,
#  'age': nan,
#  'alive': 'no',
#  'alone': False,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Southampton',
#  'embarked': 'S',
#  'fare': 23.45,
#  'parch': 2,
#  'pclass': 3,
#  'sex': 'female',
#  'sibsp': 1,
#  'survived': 0,
#  'who': 'woman'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a605'),
#  'adult_male': True,
#  'age': 26.0,
#  'alive': 'yes',
#  'alone': True,
#  'class': 'First',
#  'deck': 'C',
#  'embark_town': 'Cherbourg',
#  'embarked': 'C',
#  'fare': 30.0,
#  'parch': 0,
#  'pclass': 1,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 1,
#  'who': 'man'}
# {'_id': ObjectId('63e7ada1fe31db2740c6a606'),
#  'adult_male': True,
#  'age': 32.0,
#  'alive': 'no',
#  'alone': True,
#  'class': 'Third',
#  'deck': nan,
#  'embark_town': 'Queenstown',
#  'embarked': 'Q',
#  'fare': 7.75,
#  'parch': 0,
#  'pclass': 3,
#  'sex': 'male',
#  'sibsp': 0,
#  'survived': 0,
#  'who': 'man'}
