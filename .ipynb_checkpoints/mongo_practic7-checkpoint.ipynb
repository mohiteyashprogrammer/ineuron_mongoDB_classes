# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer 
print(db)
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
db = client["ineuron"]

# %%
collection = db["Details"]

# %%
data = [
    {
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 1-1-2023,
    "duration": "six months",
    "mode": "offline",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 15000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 14-6-2023,
    "duration": "seven months",
    "mode": "online",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 14000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 30-12-2023,
    "duration": "seven months",
    "mode": "online",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 14000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 1-1-2024,
    "duration": "eight months",
    "mode": "online ",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 17000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 30-6-2024,
    "duration": "eight months",
    "mode": "offline",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 17000,
},{
    "cource_name":["Big Data Crash Cource"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 1-7-2024,
    "duration": "one month",
    "mode": "online",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 1500,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 18-12-2024,
    "duration": "nine months",
    "mode": "online",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 18000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 1-1-2025,
    "duration": "one year",
    "mode": "online",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 20000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 1-1-2026,
    "duration": "one year",
    "mode": "online",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 17000,
},{
    "cource_name":["Data Science","Data Analytics","Web Developement","Big Data","Devops"],
    "cource_instructor":["sudhanshu" ,"anand" , "shashank" , "hitesh" , "navin"],
    "start_date": 1-1-2027,
    "duration": "nine months",
    "mode": "offline",
    "certification": "yes",
    "mockinterview": "yes",
    "price": 25000,
}
]

# %%
collection.insert_many(data)

# %%
from pprint import pprint
for i in collection.find():
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0914'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'six months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 15000,
#  'start_date': -2023}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0917'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'online ',
#  'price': 17000,
#  'start_date': -2024}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0918'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 17000,
#  'start_date': -2000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091a'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 18000,
#  'start_date': -2018}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091b'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 20000,
#  'start_date': -2025}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091c'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 17000,
#  'start_date': -2026}
# {'_id': ObjectId('63cfd5b81295d9df24ec091e'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'six months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 15000,
#  'start_date': -2023}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd5b81295d9df24ec0921'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'online ',
#  'price': 17000,
#  'start_date': -2024}
# {'_id': ObjectId('63cfd5b81295d9df24ec0922'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 17000,
#  'start_date': -2000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5b81295d9df24ec0924'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 18000,
#  'start_date': -2018}
# {'_id': ObjectId('63cfd5b81295d9df24ec0925'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 20000,
#  'start_date': -2025}
# {'_id': ObjectId('63cfd5b81295d9df24ec0926'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 17000,
#  'start_date': -2026}
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 25000,
#  'start_date': -2027}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a849'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'six months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 15000,
#  'start_date': -2023}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84c'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'online ',
#  'price': 17000,
#  'start_date': -2024}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84d'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 17000,
#  'start_date': -2000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84f'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 18000,
#  'start_date': -2018}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a850'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 20000,
#  'start_date': -2025}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a851'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 17000,
#  'start_date': -2026}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 25000,
#  'start_date': -2027}

# %%
for i in collection.find({},{'cource_instructor'}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0914'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0917'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0918'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091a'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091b'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091c'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec091e'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0921'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0922'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0924'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0925'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0926'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a849'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84c'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84d'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84f'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a850'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a851'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'),
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin']}

# %%
for i in collection.find({},{'cource_name'}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0914'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0917'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0918'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'),
#  'cource_name': ['Big Data Crash Cource']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091a'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091b'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091c'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec091e'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0921'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0922'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'),
#  'cource_name': ['Big Data Crash Cource']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0924'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0925'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0926'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a849'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84c'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84d'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'),
#  'cource_name': ['Big Data Crash Cource']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84f'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a850'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a851'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'),
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops']}

# %%
for i in collection.find({'price': 1500}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}

# %%
for i in collection.find({},{'duration'}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0914'), 'duration': 'six months'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'), 'duration': 'seven months'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'), 'duration': 'seven months'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0917'), 'duration': 'eight months'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0918'), 'duration': 'eight months'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'), 'duration': 'one month'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091a'), 'duration': 'nine months'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091b'), 'duration': 'one year'}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091c'), 'duration': 'one year'}
# {'_id': ObjectId('63cfd5b81295d9df24ec091e'), 'duration': 'six months'}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'), 'duration': 'seven months'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'), 'duration': 'seven months'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0921'), 'duration': 'eight months'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0922'), 'duration': 'eight months'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'), 'duration': 'one month'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0924'), 'duration': 'nine months'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0925'), 'duration': 'one year'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0926'), 'duration': 'one year'}
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'), 'duration': 'nine months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a849'), 'duration': 'six months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'), 'duration': 'seven months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'), 'duration': 'seven months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84c'), 'duration': 'eight months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84d'), 'duration': 'eight months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'), 'duration': 'one month'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84f'), 'duration': 'nine months'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a850'), 'duration': 'one year'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a851'), 'duration': 'one year'}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'), 'duration': 'nine months'}

# %%
for i in collection.find({},{'price'}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0914'), 'price': 15000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'), 'price': 14000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'), 'price': 14000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0917'), 'price': 17000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0918'), 'price': 17000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'), 'price': 1500}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091a'), 'price': 18000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091b'), 'price': 20000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091c'), 'price': 17000}
# {'_id': ObjectId('63cfd5b81295d9df24ec091e'), 'price': 15000}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'), 'price': 14000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'), 'price': 14000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0921'), 'price': 17000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0922'), 'price': 17000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'), 'price': 1500}
# {'_id': ObjectId('63cfd5b81295d9df24ec0924'), 'price': 18000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0925'), 'price': 20000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0926'), 'price': 17000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'), 'price': 25000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a849'), 'price': 15000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'), 'price': 14000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'), 'price': 14000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84c'), 'price': 17000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84d'), 'price': 17000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'), 'price': 1500}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84f'), 'price': 18000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a850'), 'price': 20000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a851'), 'price': 17000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'), 'price': 25000}

# %%
collection.find_one_and_update({'price': 25000},{"$set":{'price': 35000}})
# Out:
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'),
#  'cource_name': ['Data Science',
#   'Data Analytics',
#   'Web Developement',
#   'Big Data',
#   'Devops'],
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'start_date': -2027,
#  'duration': 'nine months',
#  'mode': 'offline',
#  'certification': 'yes',
#  'mockinterview': 'yes',
#  'price': 25000}

# %%
for i in collection.find({"price":35000}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd5b81295d9df24ec0927'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 35000,
#  'start_date': -2027}

# %%
collection.delete_one({"price":35000})

# %%
for i in collection.find({"price":{"$gt":20000}}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec091b'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 20000,
#  'start_date': -2025}
# {'_id': ObjectId('63cfd5b81295d9df24ec0925'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 20000,
#  'start_date': -2025}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a850'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 20000,
#  'start_date': -2025}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 25000,
#  'start_date': -2027}

# %%
collection.delete_many({ 'price': 20000})

# %%
for i in collection.find():
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0914'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'six months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 15000,
#  'start_date': -2023}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0917'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'online ',
#  'price': 17000,
#  'start_date': -2024}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0918'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 17000,
#  'start_date': -2000}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091a'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 18000,
#  'start_date': -2018}
# {'_id': ObjectId('63cfd0cb1295d9df24ec091c'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 17000,
#  'start_date': -2026}
# {'_id': ObjectId('63cfd5b81295d9df24ec091e'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'six months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 15000,
#  'start_date': -2023}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd5b81295d9df24ec0921'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'online ',
#  'price': 17000,
#  'start_date': -2024}
# {'_id': ObjectId('63cfd5b81295d9df24ec0922'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 17000,
#  'start_date': -2000}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5b81295d9df24ec0924'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 18000,
#  'start_date': -2018}
# {'_id': ObjectId('63cfd5b81295d9df24ec0926'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 17000,
#  'start_date': -2026}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a849'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'six months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 15000,
#  'start_date': -2023}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84c'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'online ',
#  'price': 17000,
#  'start_date': -2024}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84d'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'eight months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 17000,
#  'start_date': -2000}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84f'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 18000,
#  'start_date': -2018}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a851'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'one year',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 17000,
#  'start_date': -2026}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a852'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'nine months',
#  'mockinterview': 'yes',
#  'mode': 'offline',
#  'price': 25000,
#  'start_date': -2027}

# %%
for i in collection.find({"price":{"$lt":15000}}):
    pprint(i)
# Out:
# {'_id': ObjectId('63cfd0cb1295d9df24ec0915'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0916'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd0cb1295d9df24ec0919'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5b81295d9df24ec091f'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd5b81295d9df24ec0920'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd5b81295d9df24ec0923'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84a'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2015}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84b'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Data Science',
#                  'Data Analytics',
#                  'Web Developement',
#                  'Big Data',
#                  'Devops'],
#  'duration': 'seven months',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 14000,
#  'start_date': -2005}
# {'_id': ObjectId('63cfd5cdbedd7d3eb3f0a84e'),
#  'certification': 'yes',
#  'cource_instructor': ['sudhanshu', 'anand', 'shashank', 'hitesh', 'navin'],
#  'cource_name': ['Big Data Crash Cource'],
#  'duration': 'one month',
#  'mockinterview': 'yes',
#  'mode': 'online',
#  'price': 1500,
#  'start_date': -2030}

# %%
collection.delete_many({'price':{"$lte":15000}})
