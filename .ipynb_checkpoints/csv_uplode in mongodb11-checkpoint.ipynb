# %%
from pprint import pprint
import pandas as pd
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer 
print(db)
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
data = pd.read_csv("anime.csv")

# %%
db = client["100anime_data"]

# %%
collection = db["records"]

# %%
data = data.to_dict(orient="record")
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_26616\2704615251.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data = data.to_dict(orient="record")

# %%
collection.insert_many(data)

# %%
for i in  collection.find():
    pprint(i)
# Out:
# {'_id': ObjectId('63ff0e78df269baf0a0faa67'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Kaubôi bibappu',
#  'runtime': '24 min',
#  'time_line': '(1998–1999)',
#  'votes': '123,473'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa68'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Steins;Gate',
#  'runtime': '24 min',
#  'time_line': '(2011–2015)',
#  'votes': '64,600'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa69'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Rurouni Kenshin: Meiji Kenkaku Romantan: Tsuioku Hen',
#  'runtime': '118 min',
#  'time_line': '(1999)',
#  'votes': '15,198'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa6a'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Kenpuu Denki Berserk',
#  'runtime': '23 min',
#  'time_line': '(1997–1998)',
#  'votes': '42,116'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa6b'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Baccano!',
#  'runtime': '384 min',
#  'time_line': '(2007–2008)',
#  'votes': '12,087'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa6c'),
#  'gener': 'Animation,Drama,Fantasy',
#  'names': 'Mushishi',
#  'runtime': '25 min',
#  'time_line': '(2005–2014)',
#  'votes': '13,804'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa6d'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Berusaiyu no bara',
#  'runtime': '24 min',
#  'time_line': '(1979–1980)',
#  'votes': '2,104'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa6e'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Ginga Eiyuu Densetsu',
#  'runtime': '25 min',
#  'time_line': '(1988–1997)',
#  'votes': '3,897'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa6f'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Ima, soko ni iru boku',
#  'runtime': '25 min',
#  'time_line': '(1999–2000)',
#  'votes': '1,826'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa70'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Hunter x Hunter',
#  'runtime': '24 min',
#  'time_line': '(2011–2014)',
#  'votes': '105,966'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa71'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Usagi doroppu',
#  'runtime': '24 min',
#  'time_line': '(2011–2012)',
#  'votes': '3,555'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa72'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Rurôni Kenshin - Meiji kenkaku romantan',
#  'runtime': '24 min',
#  'time_line': '(1996–1998)',
#  'votes': '19,676'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa73'),
#  'gener': 'Animation,Crime,Drama',
#  'names': 'Monster',
#  'runtime': '24 min',
#  'time_line': '(2004–2005)',
#  'votes': '33,419'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa74'),
#  'gener': 'Animation,Action,Thriller',
#  'names': 'Gyakkyô burai Kaiji',
#  'runtime': '23 min',
#  'time_line': '(2007–2011)',
#  'votes': '3,343'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa75'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Mezon Ikkoku',
#  'runtime': '25 min',
#  'time_line': '(1986–1988)',
#  'votes': '1,144'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa76'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Vinland Saga',
#  'runtime': '24 min',
#  'time_line': '(2019– )',
#  'votes': '44,399'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa77'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Rupan sansei',
#  'runtime': '23 min',
#  'time_line': '(1971–1972)',
#  'votes': '2,251'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa78'),
#  'gener': 'Animation,Crime,Drama',
#  'names': 'Death Note: Desu nôto',
#  'runtime': '23 min',
#  'time_line': '(2006–2007)',
#  'votes': '333,516'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa79'),
#  'gener': 'Animation,Adventure,Comedy',
#  'names': 'Musekinin kanchô Tairâ',
#  'runtime': '24 min',
#  'time_line': '(1993–1996)',
#  'votes': '462'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa7a'),
#  'gener': 'Animation,Action,Crime',
#  'names': 'Kôkaku kidôtai: Stand Alone Complex',
#  'runtime': '24 min',
#  'time_line': '(2002–2005)',
#  'votes': '20,093'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa7b'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'GTO',
#  'runtime': '30 min',
#  'time_line': '(1999–2000)',
#  'votes': '9,794'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa7c'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Ashita no Jô',
#  'runtime': '24 min',
#  'time_line': '(1970–1971)',
#  'votes': '656'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa7d'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'One Punch Man: Wanpanman',
#  'runtime': '24 min',
#  'time_line': '(2015–2019)',
#  'votes': '164,938'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa7e'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Code Geass: Hangyaku no Lelouch',
#  'runtime': '24 min',
#  'time_line': '(2006–2008)',
#  'votes': '70,747'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa7f'),
#  'gener': 'Animation,Adventure,Drama',
#  'names': 'Romio no aoi sora',
#  'runtime': '25 min',
#  'time_line': '(1995)',
#  'votes': '1,190'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa80'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Black Lagoon',
#  'runtime': '24 min',
#  'time_line': '(2006)',
#  'votes': '15,875'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa81'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Darker Than Black: Kuro no keiyakusha',
#  'runtime': '23 min',
#  'time_line': '(2007–2010)',
#  'votes': '12,042'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa82'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'Ranma ½',
#  'runtime': '24 min',
#  'time_line': '(1989)',
#  'votes': '5,321'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa83'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Shin seiki evangerion',
#  'runtime': '25 min',
#  'time_line': '(1995–1996)',
#  'votes': '73,154'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa84'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Seirei no moribito',
#  'runtime': '25 min',
#  'time_line': '(2007)',
#  'votes': '2,779'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa85'),
#  'gener': 'Animation,Action,Crime',
#  'names': 'Gangureivu',
#  'runtime': '24 min',
#  'time_line': '(2003–2004)',
#  'votes': '5,077'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa86'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Tengen toppa gurren lagann',
#  'runtime': '24 min',
#  'time_line': '(2007)',
#  'votes': '19,006'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa87'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Kureimoa',
#  'runtime': '24 min',
#  'time_line': '(2007)',
#  'votes': '14,177'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa88'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Hagane no renkinjutsushi',
#  'runtime': '25 min',
#  'time_line': '(2003–2004)',
#  'votes': '72,431'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa89'),
#  'gener': 'Animation,Drama,Fantasy',
#  'names': 'Haibane Renmei',
#  'runtime': '24 min',
#  'time_line': '(2002– )',
#  'votes': '3,838'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa8a'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Kimetsu no Yaiba',
#  'runtime': '316 min',
#  'time_line': '(2019– )',
#  'votes': '109,496'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa8b'),
#  'gener': 'Animation,Drama,Horror',
#  'names': 'Serial Experiments Lain',
#  'runtime': '25 min',
#  'time_line': '(1998)',
#  'votes': '14,715'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa8c'),
#  'gener': 'Animation,Adventure,Drama',
#  'names': 'Kôkyô shihen Eureka Sebun',
#  'runtime': '24 min',
#  'time_line': '(2005–2006)',
#  'votes': '3,183'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa8d'),
#  'gener': 'Animation,Drama,Mystery',
#  'names': 'Death Parade',
#  'runtime': '25 min',
#  'time_line': '(2015)',
#  'votes': '17,215'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa8e'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Chôjikû Yôsai Macross',
#  'runtime': '24 min',
#  'time_line': '(1982–1983)',
#  'votes': '2,185'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa8f'),
#  'gener': 'Animation,Adventure,Fantasy',
#  'names': 'Ôkami to kôshinryô',
#  'runtime': '25 min',
#  'time_line': '(2008–2009)',
#  'votes': '4,604'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa90'),
#  'gener': 'Animation,Action,Crime',
#  'names': 'Phantom: Requiem for the Phantom',
#  'runtime': '24 min',
#  'time_line': '(2009)',
#  'votes': '1,808'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa91'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Erufen rîto',
#  'runtime': '25 min',
#  'time_line': '(2004)',
#  'votes': '34,321'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa92'),
#  'gener': 'Animation,Comedy,Romance',
#  'names': 'School Rumble',
#  'runtime': '20 min',
#  'time_line': '(2004–2010)',
#  'votes': '2,085'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa93'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'Hajime no ippo',
#  'runtime': '24 min',
#  'time_line': '(2000–2002)',
#  'votes': '7,508'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa94'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Shôjo kakumei Utena',
#  'runtime': '24 min',
#  'time_line': '(1997)',
#  'votes': '1,812'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa95'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Natsume yûjinchô',
#  'runtime': '24 min',
#  'time_line': '(2008–2017)',
#  'votes': '2,180'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa96'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Inuyasha',
#  'runtime': '24 min',
#  'time_line': '(2000–2004)',
#  'votes': '16,768'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa97'),
#  'gener': 'Animation,Adventure,Drama',
#  'names': '12 kokuki',
#  'runtime': '30 min',
#  'time_line': '(2002–2003)',
#  'votes': '2,073'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa98'),
#  'gener': 'Animation,Adventure,Drama',
#  'names': 'Kaiba',
#  'runtime': '24 min',
#  'time_line': '(2008)',
#  'votes': '1,796'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa99'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Tenkû no Esukafurône',
#  'runtime': '24 min',
#  'time_line': '(1996)',
#  'votes': '4,323'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa9a'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Yu yu hakusho',
#  'runtime': '24 min',
#  'time_line': '(1992–1995)',
#  'votes': '14,184'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa9b'),
#  'gener': 'Animation,Drama,Horror',
#  'names': 'Higurashi no naku koro ni',
#  'runtime': '30 min',
#  'time_line': '(2006)',
#  'votes': '5,963'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa9c'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'Durarara!!',
#  'runtime': '151 min',
#  'time_line': '(2010)',
#  'votes': '7,444'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa9d'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Kidô Senshi Gundam',
#  'runtime': '24 min',
#  'time_line': '(1979–1980)',
#  'votes': '2,485'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa9e'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'FLCL',
#  'runtime': '24 min',
#  'time_line': '(2000–2001)',
#  'votes': '18,315'}
# {'_id': ObjectId('63ff0e78df269baf0a0faa9f'),
#  'gener': 'Animation,Adventure,Comedy',
#  'names': 'Mirai shônen Konan',
#  'runtime': '24 min',
#  'time_line': '(1978)',
#  'votes': '4,529'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa0'),
#  'gener': 'Animation,Drama,Mystery',
#  'names': 'Gankutsu-ô',
#  'runtime': '24 min',
#  'time_line': '(2004–2005)',
#  'votes': '2,584'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa1'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'N.H.K ni yôkoso!',
#  'runtime': '25 min',
#  'time_line': '(2006)',
#  'votes': '7,150'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa2'),
#  'gener': 'Animation,Adventure,Drama',
#  'names': 'Rittai anime ie naki ko Remi',
#  'runtime': '25 min',
#  'time_line': '(1977–1978)',
#  'votes': '1,146'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa3'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Sureiyâzu',
#  'runtime': '24 min',
#  'time_line': '(1995–2009)',
#  'votes': '2,292'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa4'),
#  'gener': 'Animation,Drama,Sci-Fi',
#  'names': 'Planetes',
#  'runtime': '24 min',
#  'time_line': '(2003–2004)',
#  'votes': '3,723'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa5'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Kimi ni todoke',
#  'runtime': '24 min',
#  'time_line': '(2009–2011)',
#  'votes': '4,288'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa6'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'City Hunter',
#  'runtime': '24 min',
#  'time_line': '(1987–1991)',
#  'votes': '1,459'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa7'),
#  'gener': 'Animation,Comedy,Romance',
#  'names': 'Ôran kôkô hosutobu',
#  'runtime': '23 min',
#  'time_line': '(2006)',
#  'votes': '10,597'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa8'),
#  'gener': 'Animation,Drama,Family',
#  'names': 'Re mizeraburu: shoujo kozetto',
#  'runtime': '360 min',
#  'time_line': '(2007)',
#  'votes': '301'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaa9'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Michiko to Hatchin',
#  'runtime': '25 min',
#  'time_line': '(2008– )',
#  'votes': '1,072'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaaa'),
#  'gener': 'Animation,Action,Comedy',
#  'names': 'Bakemonogatari',
#  'runtime': '30 min',
#  'time_line': '(2009–2010)',
#  'votes': '5,967'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaab'),
#  'gener': 'Animation,Fantasy,Horror',
#  'names': 'Mononoke',
#  'runtime': '30 min',
#  'time_line': '(2007)',
#  'votes': '2,409'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaac'),
#  'gener': 'Animation,Adventure,Comedy',
#  'names': 'Purinsesu Chuchu',
#  'runtime': '28 min',
#  'time_line': '(2002–2003)',
#  'votes': '1,070'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaad'),
#  'gener': 'Animation,Crime,Drama',
#  'names': 'Rainbow: Nishakubou no shichinin',
#  'runtime': '24 min',
#  'time_line': '(2010– )',
#  'votes': '2,633'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaae'),
#  'gener': 'Animation,Adventure,Comedy',
#  'names': 'Taiyô no ko Esuteban',
#  'runtime': '24 min',
#  'time_line': '(1982–1983)',
#  'votes': '4,063'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaaf'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Sayonara zetsubô sensei',
#  'runtime': '24 min',
#  'time_line': '(2007)',
#  'votes': '952'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab0'),
#  'gener': 'Animation,Drama,Family',
#  'names': 'Akage no An',
#  'runtime': '24 min',
#  'time_line': '(1979)',
#  'votes': '1,882'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab1'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Uchû kaizoku kyaputen Hârokku',
#  'runtime': '23 min',
#  'time_line': '(1978–1979)',
#  'votes': '1,233'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab2'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Chobits',
#  'runtime': '701 min',
#  'time_line': '(2002–2003)',
#  'votes': '4,531'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab3'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Takarajima',
#  'runtime': '25 min',
#  'time_line': '(1978–1987)',
#  'votes': '1,230'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab4'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Urusei yatsura',
#  'runtime': '24 min',
#  'time_line': '(1981–1986)',
#  'votes': '1,128'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab5'),
#  'gener': 'Animation,Action,Adventure',
#  'names': "Wolf's Rain",
#  'runtime': '24 min',
#  'time_line': '(2003–2004)',
#  'votes': '7,934'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab6'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Hokuto no Ken',
#  'runtime': '50 min',
#  'time_line': '(1984–1988)',
#  'votes': '3,279'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab7'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Samurai chanpurû',
#  'runtime': '24 min',
#  'time_line': '(2004–2005)',
#  'votes': '50,478'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab8'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Ef: A Tale of Memories.',
#  'runtime': '23 min',
#  'time_line': '(2007)',
#  'votes': '807'}
# {'_id': ObjectId('63ff0e78df269baf0a0faab9'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Trigun',
#  'runtime': '165 min',
#  'time_line': '(1998)',
#  'votes': '22,511'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaba'),
#  'gener': 'Animation,Action,Fantasy',
#  'names': 'Hellsing Ultimate',
#  'runtime': '24 min',
#  'time_line': '(2006–2012)',
#  'votes': '24,245'}
# {'_id': ObjectId('63ff0e78df269baf0a0faabb'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Toradora!',
#  'runtime': '24 min',
#  'time_line': '(2008–2009)',
#  'votes': '16,492'}
# {'_id': ObjectId('63ff0e78df269baf0a0faabc'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Kaleido Star',
#  'runtime': '25 min',
#  'time_line': '(2003–2004)',
#  'votes': '936'}
# {'_id': ObjectId('63ff0e78df269baf0a0faabd'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Blood+',
#  'runtime': '26 min',
#  'time_line': '(2005–2006)',
#  'votes': '4,666'}
# {'_id': ObjectId('63ff0e78df269baf0a0faabe'),
#  'gener': 'Animation,Comedy',
#  'names': 'Golden Boy: Sasurai no o-benkyô yarô',
#  'runtime': '30 min',
#  'time_line': '(1995–1996)',
#  'votes': '6,067'}
# {'_id': ObjectId('63ff0e78df269baf0a0faabf'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'JoJo no Kimyô na Bôken',
#  'runtime': '50 min',
#  'time_line': '(2012– )',
#  'votes': '26,623'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac0'),
#  'gener': 'Animation,Comedy,Fantasy',
#  'names': 'Suzumiya Haruhi no Yûutsu',
#  'runtime': '25 min',
#  'time_line': '(2006–2009)',
#  'votes': '8,691'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac1'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'XXXHOLiC',
#  'runtime': '25 min',
#  'time_line': '(2006–2011)',
#  'votes': '1,943'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac2'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Nodame kantâbire',
#  'runtime': '25 min',
#  'time_line': '(2007–2010)',
#  'votes': '1,296'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac3'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Seikai no monshô',
#  'runtime': '253 min',
#  'time_line': '(1999)',
#  'votes': '510'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac4'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Clannad',
#  'runtime': nan,
#  'time_line': '(2007–2008)',
#  'votes': '9,703'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac5'),
#  'gener': 'Animation,Action,Adventure',
#  'names': 'Katanagatari',
#  'runtime': nan,
#  'time_line': '(2010)',
#  'votes': '1,478'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac6'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Kimagure orenji rôdo',
#  'runtime': nan,
#  'time_line': '(1985–1988)',
#  'votes': '869'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac7'),
#  'gener': 'Animation,Action,Drama',
#  'names': 'Mirai nikki',
#  'runtime': nan,
#  'time_line': '(2011–2013)',
#  'votes': '18,215'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac8'),
#  'gener': 'Animation,Drama,Romance',
#  'names': 'Koi kaze',
#  'runtime': nan,
#  'time_line': '(2004)',
#  'votes': '447'}
# {'_id': ObjectId('63ff0e78df269baf0a0faac9'),
#  'gener': 'Animation,Drama,Sci-Fi',
#  'names': 'Tekunoraizu',
#  'runtime': nan,
#  'time_line': '(2003)',
#  'votes': '2,885'}
# {'_id': ObjectId('63ff0e78df269baf0a0faaca'),
#  'gener': 'Animation,Comedy,Drama',
#  'names': 'Yojôhan shinwa taikei',
#  'runtime': nan,
#  'time_line': '(2010)',
#  'votes': '4,423'}

# %%
collection.find_one({"names":"One Punch Man: Wanpanman"})
# Out:
# {'_id': ObjectId('63ff0e78df269baf0a0faa7d'),
#  'names': 'One Punch Man: Wanpanman',
#  'time_line': '(2015–2019)',
#  'gener': 'Animation,Action,Comedy',
#  'votes': '164,938',
#  'runtime': '24 min'}
