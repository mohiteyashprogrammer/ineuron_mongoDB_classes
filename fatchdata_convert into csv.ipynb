# %%
import pandas as pd
import pandas as pd
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer 
print(db)
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
db = client["ineuron"]

# %%
collection = db["Details"]

# %%
data = list(collection.find())

# %%
df = pd.DataFrame(data)

# %%
df.to_csv("data.csv",index = False)

# %%
df
# Out:
#                          _id  \
# 0   63cfd0cb1295d9df24ec0917
# 1   63cfd0cb1295d9df24ec0918
# 2   63cfd0cb1295d9df24ec091a
# 3   63cfd0cb1295d9df24ec091c
# 4   63cfd5b81295d9df24ec0921
# 5   63cfd5b81295d9df24ec0922
# 6   63cfd5b81295d9df24ec0924
# 7   63cfd5b81295d9df24ec0926
# 8   63cfd5cdbedd7d3eb3f0a84c
# 9   63cfd5cdbedd7d3eb3f0a84d
# 10  63cfd5cdbedd7d3eb3f0a84f
# 11  63cfd5cdbedd7d3eb3f0a851
# 12  63cfd5cdbedd7d3eb3f0a852
#
#                                           cource_name  \
# 0   [Data Science, Data Analytics, Web Developemen...
# 1   [Data Science, Data Analytics, Web Developemen...
# 2   [Data Science, Data Analytics, Web Developemen...
# 3   [Data Science, Data Analytics, Web Developemen...
# 4   [Data Science, Data Analytics, Web Developemen...
# 5   [Data Science, Data Analytics, Web Developemen...
# 6   [Data Science, Data Analytics, Web Developemen...
# 7   [Data Science, Data Analytics, Web Developemen...
# 8   [Data Science, Data Analytics, Web Developemen...
# 9   [Data Science, Data Analytics, Web Developemen...
# 10  [Data Science, Data Analytics, Web Developemen...
# 11  [Data Science, Data Analytics, Web Developemen...
# 12  [Data Science, Data Analytics, Web Developemen...
#
#                               cource_instructor  start_date      duration  \
# 0   [sudhanshu, anand, shashank, hitesh, navin]       -2024  eight months
# 1   [sudhanshu, anand, shashank, hitesh, navin]       -2000  eight months
# 2   [sudhanshu, anand, shashank, hitesh, navin]       -2018   nine months
# 3   [sudhanshu, anand, shashank, hitesh, navin]       -2026      one year
# 4   [sudhanshu, anand, shashank, hitesh, navin]       -2024  eight months
# 5   [sudhanshu, anand, shashank, hitesh, navin]       -2000  eight months
# 6   [sudhanshu, anand, shashank, hitesh, navin]       -2018   nine months
# 7   [sudhanshu, anand, shashank, hitesh, navin]       -2026      one year
# 8   [sudhanshu, anand, shashank, hitesh, navin]       -2024  eight months
# 9   [sudhanshu, anand, shashank, hitesh, navin]       -2000  eight months
# 10  [sudhanshu, anand, shashank, hitesh, navin]       -2018   nine months
# 11  [sudhanshu, anand, shashank, hitesh, navin]       -2026      one year
# 12  [sudhanshu, anand, shashank, hitesh, navin]       -2027   nine months
#
#        mode certification mockinterview  price
# 0   online            yes           yes  17000
# 1   offline           yes           yes  17000
# 2    online           yes           yes  18000
# 3    online           yes           yes  17000
# 4   online            yes           yes  17000
# 5   offline           yes           yes  17000
# 6    online           yes           yes  18000
# 7    online           yes           yes  17000
# 8   online            yes           yes  17000
# 9   offline           yes           yes  17000
# 10   online           yes           yes  18000
# 11   online           yes           yes  17000
# 12  offline           yes           yes  25000
