# %%
from pprint import pprint
import pandas as pd
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer 
print(db)
import requests

url = "https://flight-data4.p.rapidapi.com/get_airline_flights"

querystring = {"airline":"SIA"}

headers = {
"X-RapidAPI-Key": "613000080bmshfb1cddd260051fap14822djsn46c825944932",
"X-RapidAPI-Host": "flight-data4.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

data = response.json()
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
client.list_database_names()
# Out:
# ['Test',
#  'code_with_harry',
#  'covid-19',
#  'cricbuzz',
#  'cricket',
#  'ineuron',
#  'planets',
#  'police_line',
#  'school',
#  'taxis',
#  'titanic',
#  'admin',
#  'local']

# %%
db = client["flight"]

# %%
collection = db["records"]

# %%
collection.insert_many(data)

# %%
data = list(collection.find())

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#                          _id airline  altitude arrival      arrival_position  \
# 0   63f4e5233df915454690e719     SIA     40000     JFK   [40.6398, -73.7789]
# 1   63f4e5233df915454690e71a     SIA        63     LHR  [51.4706, -0.461941]
# 2   63f4e5233df915454690e71b     SIA     40350     SEA    [47.449, -122.309]
# 3   63f4e5233df915454690e71c     SIA     40000     FRA    [50.0264, 8.54313]
# 4   63f4e5233df915454690e71d     SIA     40996     SIN    [1.35019, 103.994]
# 5   63f4e5233df915454690e71e     SIA     40000     SIN    [1.35019, 103.994]
# 6   63f4e5233df915454690e71f     SIA     41500     SIN    [1.35019, 103.994]
# 7   63f4e5233df915454690e720     SIA     40000     LHR  [51.4706, -0.461941]
# 8   63f4e5233df915454690e721     SIA     39000     SFO    [37.619, -122.375]
# 9   63f4e5233df915454690e722     SIA     40500     SIN    [1.35019, 103.994]
# 10  63f4e5233df915454690e723     SIA     36000     SIN    [1.35019, 103.994]
# 11  63f4e5233df915454690e724     SIA      5175     JFK   [40.6398, -73.7789]
# 12  63f4e5233df915454690e725     SIA     27150     BOM    [19.0887, 72.8679]
# 13  63f4e5233df915454690e726     SIA     45400     SIN    [1.35019, 103.994]
# 14  63f4e5233df915454690e727     SIA     35850     SIN    [1.35019, 103.994]
# 15  63f4e5233df915454690e728     SIA     40350     SIN    [1.35019, 103.994]
# 16  63f4e5233df915454690e729     SIA     35000     SIN    [1.35019, 103.994]
# 17  63f4e5233df915454690e72a     SIA     43000     SIN    [1.35019, 103.994]
# 18  63f4e5233df915454690e72b     SIA     39000     SIN    [1.35019, 103.994]
# 19  63f4e5233df915454690e72c     SIA     37000     LAX   [33.9425, -118.408]
# 20  63f4e5233df915454690e72d     SIA     36000     SIN    [1.35019, 103.994]
# 21  63f4e5233df915454690e72e     SIA     38350     IAH   [29.9844, -95.3414]
# 22  63f4e5233df915454690e72f     SIA     37000     CGK   [-6.12557, 106.656]
# 23  63f4e5233df915454690e730     SIA     29975     AMD    [23.0772, 72.6347]
# 24  63f4e5233df915454690e731     SIA     37000     SIN    [1.35019, 103.994]
# 25  63f4e5233df915454690e732     SIA       375     PER   [-31.9403, 115.967]
# 26  63f4e5233df915454690e733     SIA     37025     SIN    [1.35019, 103.994]
# 27  63f4e5233df915454690e734     SIA     34725     SIN    [1.35019, 103.994]
# 28  63f4e5233df915454690e735     SIA     29850     KTM    [27.6966, 85.3591]
# 29  63f4e5233df915454690e736     SIA     39000     SIN    [1.35019, 103.994]
# 30  63f4e5233df915454690e737     SIA     37050     SIN    [1.35019, 103.994]
# 31  63f4e5233df915454690e738     SIA     37000     SHJ    [25.3286, 55.5172]
# 32  63f4e5233df915454690e739     SIA     38000     HNL   [21.3187, -157.922]
# 33  63f4e5233df915454690e73a     SIA     36000     HYD    [17.2313, 78.4299]
# 34  63f4e5233df915454690e73b     SIA     34000     SHJ    [25.3286, 55.5172]
# 35  63f4e5233df915454690e73c     SIA     36025     COK     [10.152, 76.4019]
# 36  63f4e5233df915454690e73d     SIA     37975     MAA      [12.99, 80.1693]
# 37  63f4e5233df915454690e73e     SIA     43000     BLR    [13.1989, 77.7056]
# 38  63f4e5233df915454690e73f     SIA     34000     MLE    [4.19183, 73.5291]
# 39  63f4e5233df915454690e740     SIA     39450     SIN    [1.35019, 103.994]
# 40  63f4e5233df915454690e741     SIA     38000     DAC    [23.8433, 90.3978]
# 41  63f4e5233df915454690e742     SIA     34000     CCU    [22.6547, 88.4467]
# 42  63f4e5233df915454690e743     SIA     39000     SIN    [1.35019, 103.994]
# 43  63f4e5233df915454690e744     SIA     36004     LAX   [33.9425, -118.408]
# 44  63f4e5233df915454690e745     SIA     39000     SYD   [-33.9461, 151.177]
# 45  63f4e5233df915454690e746     SIA     36000     SIN    [1.35019, 103.994]
# 46  63f4e5233df915454690e747     SIA     41500     SIN    [1.35019, 103.994]
# 47  63f4e5233df915454690e748     SIA     37000     BNE   [-27.3842, 153.117]
# 48  63f4e5233df915454690e749     SIA     35000     ICN    [37.4691, 126.451]
# 49  63f4e5233df915454690e74a     SIA     26800     SIN    [1.35019, 103.994]
# 50  63f4e5233df915454690e74b     SIA     39000     MEL   [-37.6733, 144.843]
# 51  63f4e5233df915454690e74c     SIA     30004     SIN    [1.35019, 103.994]
# 52  63f4e5233df915454690e74d     SIA     36000     SIN    [1.35019, 103.994]
# 53  63f4e5233df915454690e74e     SIA     36000     SIN    [1.35019, 103.994]
# 54  63f4e5233df915454690e74f     SIA     40000     COK     [10.152, 76.4019]
# 55  63f4e5233df915454690e750     SIA     40000     CMB    [7.18076, 79.8841]
# 56  63f4e5233df915454690e751     SIA     31000     AKL   [-37.0081, 174.792]
# 57  63f4e5233df915454690e752     SIA     25750     HND     [35.5523, 139.78]
#
#    departure  flight groundspeed     heading  latitude  longitude  \
# 0        SIN    SQ24       530.3   66.514575  61.34674 -151.85999
# 1        SIN   SQ308          10   89.850462  51.47515   -0.46209
# 2        SIN    SQ28         556  289.066286  45.53893 -112.01104
# 3        SIN   SQ326         420  305.498741  43.86259   22.54270
# 4        JFK    SQ23         551  140.924438  30.62077   59.39990
# 5        LAX    SQ35         490  253.679438  12.47700  140.43800
# 6        SFO    SQ33         484  253.551816  12.53320  140.63300
# 7        SIN   SQ318         400  275.494939  39.91431   35.36926
# 8        SIN    SQ34       548.1   43.743369  21.83086  123.20770
# 9        LAX    SQ37         469  251.140855  19.38280  161.15800
# 10       CDG   SQ335         542  143.849262  29.29970   60.59935
# 11       FRA    SQ26       258.8  224.279469  40.47130  -73.34949
# 8        9V-SGD   ADSB      ADS-B     1676993664000  A359
# 9        9V-SJA   SATE         ADS-C  1676993547333  A359
# 10       9V-SNB   ADSB  EXTRPI000983  1676993678000  B77W
# 11       9V-SKY   ADSB  EXTRPI016174  1676993697000  A388
# 12       9V-SKZ   ADSB  PGANRB300716  1676993700830  A388         -2110
# 13       9V-SHD   ADSB  EXTRPI014877  1676993667000  A359
# 14       9V-SWW   ADSB  EXTRPI000983  1676993675000  B77W
# 15       9V-SMN   ESTI     ESTIMATED  1676993683864  A359
# 16       9V-SNA   ESTI     ESTIMATED  1676993691919  B77W
# 17       9V-SHE   ADSB  PGANRB500922  1676993697000  A359
# 18       9V-SMJ   ADSB  PGANRB501068  1676993696000  A359
# 19       9V-SNC   SATE         ADS-C  1676993323750  B77W
# 20       9V-SWB   ADSB  PGANRB500330  1676993698000  B77W
# 21       9V-SMT   ADSB  EXTRPI000457  1676993679000  A359
# 22       9V-SWS   ADSB  PGANRB300702  1676993700371  B77W
# 23       9V-SHL   ADSB  PGANRB501411  1676993697000  A359         -1024
# 24       9V-SKW   ADSB  EXTRPI001178  1676993695000  A388           -60
# 25       9V-SCL   ADSB  EXTRPI208966  1676993699000  B78X          -570
# 26       9V-SMM   ESTI     ESTIMATED  1676993651820  A359          -120
# 27       9V-SGG   ADSB  PGANRB400026  1676993699000  A359           700
# 28       9V-MBP   ADSB  EXTRPI003163  1676993693000  B38M
# 29       9V-SMF   ESTI     ESTIMATED  1676993683864  A359           120
# 30       9V-SML   ESTI     ESTIMATED  1676993683864  A359          -320
# 31       9V-SFI   ADSB      ADS-B     1676993670000  B744
# 32       9V-DHA   SATE         ADS-C  1676993609460  B77L
# 33       9V-MBA   ESTI     ESTIMATED  1676993699935  B38M
# 34       9V-SFK   ADSB  EXTRPI003163  1676993700000  B744
# 35       9V-MBC   ESTI     ESTIMATED  1676993699935  B38M
# 36       9V-SCO   ADSB  EXTRPI014616  1676993685000  B78X
# 37       9V-SHS   ADSB  EXTRPI014616  1676993698000  A359
# 38       9V-MBK   ESTI     ESTIMATED  1676993699935  B38M
# 39       9V-SMR   ESTI     ESTIMATED  1676993699935  A359
# 40       9V-SHU   ESTI     ESTIMATED  1676993691919  A359
# 41       9V-MBF   ESTI     ESTIMATED  1676993675861  B38M
# 42       9V-SMA   ADSB  PGANRB400008  1676993698000  A359
# 43       9V-SMY   SATE         ADS-C  1676993700027  A359           -16
# 44       9V-SHT   ADSB  PGANRB501421  1676993695000  A359
# 45       9V-SWZ   ADSB  PGANRB400092  1676993699000  B77W
# 46       9V-SHW   ADSB  PGANRB500349  1676993696000  A359
# 47       9V-SHV   ADSB  PGANRB501011  1676993699000  A359
# 48       9V-DHB   ESTI     ESTIMATED  1676993699935  B77L
# 49       9V-SCK   ADSB  EXTSHA194528  1676993699855  B78X         -2368
# 50       9V-SHC   ADSB  PGANRB400499  1676993699000  A359
# 51       9V-SHG   SATE         ADS-C  1676993367889  A359
# 52       9V-SCI   SATE         ADS-C  1676993524175  B78X
# 53       9V-SCF   ESTI     ESTIMATED  1676993699935  B78X
# 54       9V-MBE   ADSB  EXTRPI024043  1676993695000  B38M
# 55       9V-SHJ   ADSB  PGANRB501345  1676993698000  A359
# 56       9V-SWR   ADSB      ADS-B     1676993664000  B77W
# 57       9V-SHF   ADSB  EXTSHA194528  1676993699001  A359          1216
