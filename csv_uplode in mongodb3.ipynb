# %%
import seaborn as sns
import pandas as pd
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer 
print(db)
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset("planets")

# %%
db = client["planets"]

# %%
collection = db["records"]

# %%
data = data.to_dict(orient="record")
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_20340\2704615251.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data = data.to_dict(orient="record")

# %%
collection.insert_many(data)

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('63ece988ca290a73c9671a6d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 269.3, 'mass': 7.1, 'distance': 77.4, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671a6e'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 874.774, 'mass': 2.21, 'distance': 56.95, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a6f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 763.0, 'mass': 2.6, 'distance': 19.84, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671a70'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 326.03, 'mass': 19.4, 'distance': 110.62, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671a71'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 516.22, 'mass': 10.5, 'distance': 119.47, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a72'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 185.84, 'mass': 4.8, 'distance': 76.39, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a73'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1773.4, 'mass': 4.64, 'distance': 18.15, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671a74'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 798.5, 'mass': nan, 'distance': 21.41, 'year': 1996}
# {'_id': ObjectId('63ece988ca290a73c9671a75'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 993.3, 'mass': 10.3, 'distance': 73.1, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a76'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 452.8, 'mass': 1.99, 'distance': 74.79, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671a77'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 883.0, 'mass': 0.86, 'distance': 74.79, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671a78'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 335.1, 'mass': 9.88, 'distance': 39.43, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a79'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 479.1, 'mass': 3.88, 'distance': 97.28, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a7a'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 1078.0, 'mass': 2.53, 'distance': 14.08, 'year': 1996}
# {'_id': ObjectId('63ece988ca290a73c9671a7b'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 2391.0, 'mass': 0.54, 'distance': 14.08, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671a7c'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 14002.0, 'mass': 1.64, 'distance': 14.08, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a7d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 4.230785, 'mass': 0.472, 'distance': 15.36, 'year': 1995}
# {'_id': ObjectId('63ece988ca290a73c9671a7e'), 'method': 'Radial Velocity', 'number': 5, 'orbital_period': 14.651, 'mass': 0.8, 'distance': 12.53, 'year': 1996}
# {'_id': ObjectId('63ece988ca290a73c9671a7f'), 'method': 'Radial Velocity', 'number': 5, 'orbital_period': 44.38, 'mass': 0.165, 'distance': 12.53, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671a80'), 'method': 'Radial Velocity', 'number': 5, 'orbital_period': 4909.0, 'mass': 3.53, 'distance': 12.53, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671a81'), 'method': 'Radial Velocity', 'number': 5, 'orbital_period': 0.73654, 'mass': nan, 'distance': 12.53, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671a82'), 'method': 'Radial Velocity', 'number': 5, 'orbital_period': 261.2, 'mass': 0.172, 'distance': 12.53, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671a83'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 4.215, 'mass': 0.016, 'distance': 8.52, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a84'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 38.021, 'mass': 0.057, 'distance': 8.52, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a85'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 123.01, 'mass': 0.072, 'distance': 8.52, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a86'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 116.6884, 'mass': nan, 'distance': 18.11, 'year': 1996}
# {'_id': ObjectId('63ece988ca290a73c9671a87'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 691.9, 'mass': nan, 'distance': 81.5, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671a88'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 952.7, 'mass': 5.3, 'distance': 97.18, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a89'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 181.4, 'mass': 3.2, 'distance': 45.52, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671a8a'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 45.52, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671a8b'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 165.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671a8c'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 140.0, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671a8d'), 'method': 'Eclipse Timing Variations', 'number': 1, 'orbital_period': 10220.0, 'mass': 6.05, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671a8e'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': nan, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a8f'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 145.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671a90'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 139.0, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671a91'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 18.39, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671a92'), 'method': 'Eclipse Timing Variations', 'number': 2, 'orbital_period': 5767.0, 'mass': nan, 'distance': 130.72, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a93'), 'method': 'Eclipse Timing Variations', 'number': 2, 'orbital_period': 3321.0, 'mass': nan, 'distance': 130.72, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a94'), 'method': 'Eclipse Timing Variations', 'number': 2, 'orbital_period': 5573.55, 'mass': nan, 'distance': 500.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671a95'), 'method': 'Eclipse Timing Variations', 'number': 2, 'orbital_period': 2883.5, 'mass': nan, 'distance': 500.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671a96'), 'method': 'Eclipse Timing Variations', 'number': 1, 'orbital_period': 2900.0, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671a97'), 'method': 'Eclipse Timing Variations', 'number': 1, 'orbital_period': 4343.5, 'mass': 4.2, 'distance': nan, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671a98'), 'method': 'Eclipse Timing Variations', 'number': 2, 'orbital_period': 5840.0, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671a99'), 'method': 'Eclipse Timing Variations', 'number': 2, 'orbital_period': 1916.25, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671a9a'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 380.8, 'mass': 1.8, 'distance': 20.21, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671a9b'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3.2357, 'mass': 0.0036, 'distance': 1.35, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671a9c'), 'method': 'Imaging', 'number': 1, 'orbital_period': 6000.0, 'mass': nan, 'distance': 19.28, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671a9d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2502.0, 'mass': 1.55, 'distance': 3.22, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671a9e'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 417.9, 'mass': nan, 'distance': 70.42, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671a9f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 594.9, 'mass': 7.6, 'distance': 47.53, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671aa0'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 428.5, 'mass': 8.78, 'distance': 38.52, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671aa1'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 903.3, 'mass': 1.85, 'distance': 13.79, 'year': 2003}
# {'_id': ObjectId('63ece988ca290a73c9671aa2'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1251.0, 'mass': nan, 'distance': 31.12, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671aa3'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 52.03, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671aa4'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 136.75, 'mass': 2.8, 'distance': 62.66, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671aa5'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 530.32, 'mass': nan, 'distance': 46.84, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671aa6'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 3186.0, 'mass': nan, 'distance': 46.84, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671aa7'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 277.02, 'mass': 1.7, 'distance': 80.64, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671aa8'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 187.83, 'mass': nan, 'distance': 84.03, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671aa9'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1630.0, 'mass': nan, 'distance': 56.31, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671aaa'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 39.845, 'mass': 1.04, 'distance': 17.43, 'year': 1997}
# {'_id': ObjectId('63ece988ca290a73c9671aab'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3.3135, 'mass': 3.9, 'distance': 15.6, 'year': 1996}
# {'_id': ObjectId('63ece988ca290a73c9671aac'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 305.5, 'mass': 20.6, 'distance': 92.51, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671aad'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 4.617033, 'mass': 0.6876, 'distance': 13.47, 'year': 1996}
# {'_id': ObjectId('63ece988ca290a73c9671aae'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 241.258, 'mass': 1.981, 'distance': 13.47, 'year': 1999}
# {'_id': ObjectId('63ece988ca290a73c9671aaf'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 1276.46, 'mass': 4.132, 'distance': 13.47, 'year': 1999}
# {'_id': ObjectId('63ece988ca290a73c9671ab0'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 3848.86, 'mass': 1.059, 'distance': 13.47, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ab1'), 'method': 'Imaging', 'number': 1, 'orbital_period': 318280.0, 'mass': nan, 'distance': 7.69, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671ab2'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 145.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671ab3'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 36.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ab4'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 140.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ab5'), 'method': 'Imaging', 'number': 1, 'orbital_period': 4639.15, 'mass': nan, 'distance': 12.21, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ab6'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 52.4, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671ab7'), 'method': 'Imaging', 'number': 1, 'orbital_period': 7336.5, 'mass': nan, 'distance': 25.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ab8'), 'method': 'Imaging', 'number': 1, 'orbital_period': 8679.7, 'mass': nan, 'distance': 26.67, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ab9'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 655.6, 'mass': 5.1, 'distance': 37.54, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671aba'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 714.3, 'mass': 10.6, 'distance': nan, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671abb'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3.48777, 'mass': nan, 'distance': 80.0, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671abc'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 5.6, 'mass': 0.045, 'distance': 42.09, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671abd'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 237.6, 'mass': 0.33, 'distance': 42.09, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671abe'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 3.8728, 'mass': 0.027, 'distance': 20.1, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671abf'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 125.94, 'mass': 0.17, 'distance': 20.1, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ac0'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 268.94, 'mass': 1.47, 'distance': 50.03, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ac1'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 137.48, 'mass': 1.11, 'distance': 175.44, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ac2'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 379.63, 'mass': 21.42, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ac3'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 621.99, 'mass': 12.47, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ac4'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 578.2, 'mass': nan, 'distance': nan, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671ac5'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 392.6, 'mass': 0.91, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ac6'), 'method': 'Imaging', 'number': 1, 'orbital_period': 10037.5, 'mass': nan, 'distance': 23.1, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ac7'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': nan, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671ac8'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.5089557, 'mass': nan, 'distance': nan, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671ac9'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.7429935, 'mass': nan, 'distance': 200.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671aca'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.2568, 'mass': nan, 'distance': 680.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671acb'), 'method': 'Transit', 'number': 1, 'orbital_period': 9.20205, 'mass': nan, 'distance': nan, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671acc'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.0378962, 'mass': nan, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671acd'), 'method': 'Transit', 'number': 1, 'orbital_period': 8.886593, 'mass': nan, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ace'), 'method': 'Transit', 'number': 2, 'orbital_period': 0.853585, 'mass': nan, 'distance': 150.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671acf'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 3.698, 'mass': nan, 'distance': 150.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ad0'), 'method': 'Transit', 'number': 1, 'orbital_period': 6.21229, 'mass': nan, 'distance': 380.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ad1'), 'method': 'Transit', 'number': 1, 'orbital_period': 95.2738, 'mass': nan, 'distance': 460.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ad2'), 'method': 'Transit', 'number': 1, 'orbital_period': 13.2406, 'mass': nan, 'distance': 345.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ad3'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.99433, 'mass': nan, 'distance': 560.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ad4'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.828042, 'mass': nan, 'distance': 1150.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ad5'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.03519, 'mass': nan, 'distance': 1060.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ad6'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.51214, 'mass': nan, 'distance': 1340.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671ad7'), 'method': 'Transit', 'number': 1, 'orbital_period': 5.35227, 'mass': nan, 'distance': 840.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ad8'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.7681, 'mass': nan, 'distance': 920.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ad9'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.9000693, 'mass': nan, 'distance': 870.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ada'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.89713, 'mass': nan, 'distance': 770.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671adb'), 'method': 'Transit', 'number': 1, 'orbital_period': 9.24285, 'mass': nan, 'distance': 1230.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671adc'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.6313, 'mass': nan, 'distance': 600.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671add'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.57532, 'mass': nan, 'distance': nan, 'year': 2014}
# {'_id': ObjectId('63ece988ca290a73c9671ade'), 'method': 'Astrometry', 'number': 1, 'orbital_period': 246.36, 'mass': nan, 'distance': 20.77, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671adf'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 15.76491, 'mass': 3.91, 'distance': 10.91, 'year': 1999}
# {'_id': ObjectId('63ece988ca290a73c9671ae0'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 8.631, 'mass': 0.035, 'distance': 14.97, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ae1'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 25.6, 'mass': 0.024, 'distance': 14.97, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ae2'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 603.0, 'mass': 0.079, 'distance': 14.97, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ae3'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2288.0, 'mass': 0.82, 'distance': 12.12, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671ae4'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 692.0, 'mass': 1.894, 'distance': 15.1, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671ae5'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 7100.0, 'mass': 1.6, 'distance': 15.1, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ae6'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 4100.0, 'mass': 2.3, 'distance': 20.03, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671ae7'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 7.3709, 'mass': 0.018, 'distance': 9.04, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671ae8'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2.64385, 'mass': nan, 'distance': 10.23, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671ae9'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 17.95, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671aea'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 5.36874, 'mass': 0.049, 'distance': 6.27, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671aeb'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 12.9292, 'mass': 0.017, 'distance': 6.27, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671aec'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 66.8, 'mass': 0.022, 'distance': 6.27, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671aed'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 3.14942, 'mass': 0.006, 'distance': 6.27, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671aee'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 598.3, 'mass': 0.328, 'distance': 10.32, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671aef'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 7.2004, 'mass': 0.018, 'distance': 6.8, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671af0'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 28.14, 'mass': 0.012, 'distance': 6.8, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671af1'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 91.61, 'mass': 0.016, 'distance': 6.8, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671af2'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 62.24, 'mass': 0.008, 'distance': 6.8, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671af3'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 39.026, 'mass': 0.008, 'distance': 6.8, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671af4'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 256.2, 'mass': 0.014, 'distance': 6.8, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671af5'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 4.6938, 'mass': 0.035, 'distance': 4.54, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671af6'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 1050.3, 'mass': 4.95, 'distance': 16.13, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671af7'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 3.6, 'mass': 0.014, 'distance': 16.13, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671af8'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 35.37, 'mass': 0.036, 'distance': 16.13, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671af9'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3416.0, 'mass': 0.64, 'distance': 4.94, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671afa'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1845.0, 'mass': 0.91, 'distance': 8.77, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671afb'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 61.1166, 'mass': 2.2756, 'distance': 4.7, 'year': 1998}
# {'_id': ObjectId('63ece988ca290a73c9671afc'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 30.0881, 'mass': 0.7142, 'distance': 4.7, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671afd'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 1.93778, 'mass': 0.021, 'distance': 4.7, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671afe'), 'method': 'Radial Velocity', 'number': 4, 'orbital_period': 124.26, 'mass': 0.046, 'distance': 4.7, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671aff'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.58040482, 'mass': nan, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b00'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 133.71, 'mass': 3.37, 'distance': 17.62, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671b01'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3.33714, 'mass': nan, 'distance': 25.2, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b02'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2.64561, 'mass': 0.022, 'distance': 19.8, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b03'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 145.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b04'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.4652934, 'mass': nan, 'distance': 139.0, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671b05'), 'method': 'Transit', 'number': 1, 'orbital_period': 5.6334729, 'mass': nan, 'distance': 135.32, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b06'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.899736, 'mass': nan, 'distance': 138.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b07'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.056536, 'mass': nan, 'distance': 314.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b08'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.788491, 'mass': nan, 'distance': 342.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b09'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.852985, 'mass': nan, 'distance': 261.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b0a'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.0763776, 'mass': nan, 'distance': 230.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b0b'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.92289, 'mass': nan, 'distance': 480.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b0c'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.2130598, 'mass': nan, 'distance': 142.5, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b0d'), 'method': 'Transit', 'number': 2, 'orbital_period': 2.91626, 'mass': nan, 'distance': 214.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b0e'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 428.5, 'mass': 15.2, 'distance': 214.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b0f'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.627669, 'mass': nan, 'distance': 205.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b10'), 'method': 'Transit', 'number': 1, 'orbital_period': 10.863502, 'mass': nan, 'distance': 190.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b11'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.77596, 'mass': nan, 'distance': 235.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b12'), 'method': 'Transit', 'number': 2, 'orbital_period': 10.338523, 'mass': nan, 'distance': 90.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b13'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 5584.0, 'mass': 3.4, 'distance': 90.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b14'), 'method': 'Transit', 'number': 1, 'orbital_period': 5.508023, 'mass': nan, 'distance': 166.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b15'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.008778, 'mass': nan, 'distance': 215.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b16'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.875317, 'mass': nan, 'distance': 70.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b17'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.124481, 'mass': nan, 'distance': 254.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b18'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.21222, 'mass': nan, 'distance': 82.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b19'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.212884, 'mass': nan, 'distance': 393.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b1a'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.35524, 'mass': nan, 'distance': 396.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b1b'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.652836, 'mass': nan, 'distance': 297.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b1c'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.234516, 'mass': nan, 'distance': 134.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b1d'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.039577, 'mass': nan, 'distance': 204.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b1e'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.257215, 'mass': nan, 'distance': 395.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b1f'), 'method': 'Transit', 'number': 1, 'orbital_period': 5.723186, 'mass': nan, 'distance': 322.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b20'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.810595, 'mass': nan, 'distance': 193.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b21'), 'method': 'Transit', 'number': 2, 'orbital_period': 5.005425, 'mass': nan, 'distance': 354.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b22'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 1022.0, 'mass': 3.4, 'distance': 354.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b23'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.150008, 'mass': nan, 'distance': 283.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b24'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.474474, 'mass': nan, 'distance': 387.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b25'), 'method': 'Transit', 'number': 1, 'orbital_period': 5.452654, 'mass': nan, 'distance': 257.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b26'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.646706, 'mass': nan, 'distance': 535.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b27'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.327347, 'mass': nan, 'distance': 317.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b28'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.797436, 'mass': nan, 'distance': 411.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b29'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.640382, 'mass': nan, 'distance': 249.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b2a'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.54387, 'mass': nan, 'distance': 642.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b2b'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.457243, 'mass': nan, 'distance': 501.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b2c'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.694047, 'mass': nan, 'distance': 344.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b2d'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.641878, 'mass': nan, 'distance': 447.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b2e'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.332687, 'mass': nan, 'distance': 542.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b2f'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.691548, 'mass': nan, 'distance': 322.0, 'year': 2014}
# {'_id': ObjectId('63ece988ca290a73c9671b30'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.446459, 'mass': nan, 'distance': 303.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b31'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.354133, 'mass': nan, 'distance': 360.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671b32'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.547851, 'mass': nan, 'distance': 453.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671b33'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 349.7, 'mass': 1.25, 'distance': 25.64, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671b34'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 6005.0, 'mass': 5.3, 'distance': 25.64, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b35'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 5.7727, 'mass': 0.024, 'distance': 23.44, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b36'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 13.505, 'mass': 0.0186, 'distance': 23.44, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b37'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 431.8, 'mass': 3.1, 'distance': 167.5, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b38'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 533.0, 'mass': 6.1, 'distance': 7.01, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b39'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1183.0, 'mass': 4.9, 'distance': 89.85, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b3a'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3.4442, 'mass': 0.48, 'distance': 53.71, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b3b'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 311.6, 'mass': 1.6, 'distance': 115.21, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671b3c'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 62.218, 'mass': 0.229, 'distance': 11.11, 'year': 2003}
# {'_id': ObjectId('63ece988ca290a73c9671b3d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 526.62, 'mass': 1.56, 'distance': 44.05, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b3e'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 829.0, 'mass': 0.8, 'distance': 32.7, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671b3f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 15.609, 'mass': 0.0405, 'distance': 21.85, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b40'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 431.88, 'mass': 2.07, 'distance': 77.82, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671b41'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 356.0, 'mass': 2.3, 'distance': 131.41, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b42'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 360.2, 'mass': 2.37, 'distance': 56.5, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b43'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 2732.0, 'mass': 2.37, 'distance': 56.5, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b44'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 675.0, 'mass': 1.94, 'distance': 100.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b45'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 777.0, 'mass': 1.96, 'distance': 53.28, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b46'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 792.6, 'mass': nan, 'distance': 58.17, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b47'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 177.11, 'mass': 7.6, 'distance': 150.6, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b48'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 22.09, 'mass': 0.48, 'distance': 40.32, 'year': 2003}
# {'_id': ObjectId('63ece988ca290a73c9671b49'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2496.0, 'mass': 1.65, 'distance': 55.01, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b4a'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 615.0, 'mass': 0.29, 'distance': 35.88, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b4b'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 1275.0, 'mass': 1.11, 'distance': 38.52, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b4c'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 4046.0, 'mass': 2.0, 'distance': 38.52, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b4d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 5.3978, 'mass': 0.029, 'distance': 16.82, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b4e'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1313.0, 'mass': 0.63, 'distance': 56.34, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b4f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 227.0, 'mass': 1.8, 'distance': 44.15, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b50'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1634.0, 'mass': 14.2, 'distance': 38.26, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b51'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 30.052, 'mass': 0.7, 'distance': 52.85, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b52'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 192.9, 'mass': 1.82, 'distance': 52.85, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b53'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 5.75962, 'mass': 0.041, 'distance': 39.39, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b54'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 16.3567, 'mass': 0.038, 'distance': 39.39, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b55'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 49.747, 'mass': 0.08, 'distance': 39.39, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b56'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 122.72, 'mass': 0.074, 'distance': 39.39, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b57'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 602.0, 'mass': 0.067, 'distance': 39.39, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b58'), 'method': 'Radial Velocity', 'number': 6, 'orbital_period': 2248.0, 'mass': 0.205, 'distance': 39.39, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b59'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 989.2, 'mass': 0.94, 'distance': 17.35, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671b5a'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1075.2, 'mass': 6.21, 'distance': 32.56, 'year': 1999}
# {'_id': ObjectId('63ece988ca290a73c9671b5b'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 1270.2, 'mass': 3.44, 'distance': 53.82, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b5c'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 170.455, 'mass': 0.82, 'distance': 53.82, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b5d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 711.0, 'mass': 6.54, 'distance': 66.49, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b5e'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 1945.0, 'mass': 0.622, 'distance': 33.98, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b5f'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 37.91, 'mass': 0.0788, 'distance': 33.98, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b60'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 262.709, 'mass': 2.3, 'distance': 37.16, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671b61'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 1708.0, 'mass': 1.92, 'distance': 37.16, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b62'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 471.6, 'mass': 14.0, 'distance': 300.3, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b63'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 14.182, 'mass': 0.0325, 'distance': 28.6, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b64'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 53.832, 'mass': 0.036, 'distance': 28.6, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b65'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 19.382, 'mass': 0.865, 'distance': 66.89, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671b66'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 931.0, 'mass': 5.13, 'distance': 66.89, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671b67'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 4218.0, 'mass': 1.88, 'distance': 45.52, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b68'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 75.523, 'mass': 0.26, 'distance': 35.91, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671b69'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 17.24, 'mass': 0.0696, 'distance': 25.54, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b6a'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 990.0, 'mass': 4.4, 'distance': 59.84, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b6b'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 465.1, 'mass': 14.3, 'distance': 50.18, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b6c'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 359.9, 'mass': 4.6, 'distance': nan, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b6d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 21.21663, 'mass': nan, 'distance': 78.25, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671b6e'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 772.0, 'mass': 2.7, 'distance': 127.88, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b6f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 466.2, 'mass': 1.37, 'distance': 22.38, 'year': 2003}
# {'_id': ObjectId('63ece988ca290a73c9671b70'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 11.849, 'mass': 0.0378, 'distance': 43.08, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b71'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 33.823, 'mass': 0.0422, 'distance': 43.08, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b72'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 500.0, 'mass': 1.07, 'distance': 27.13, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b73'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 18.315, 'mass': 0.0085, 'distance': 6.06, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b74'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 40.114, 'mass': 0.00755, 'distance': 6.06, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b75'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 90.309, 'mass': 0.0151, 'distance': 6.06, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b76'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 29.15, 'mass': 0.0379, 'distance': 35.89, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b77'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 85.131, 'mass': 0.0496, 'distance': 35.89, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b78'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 591.9, 'mass': 1.9, 'distance': 36.02, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671b79'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 380.85, 'mass': 1.99, 'distance': 44.5, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671b7a'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 22.656, 'mass': 0.0322, 'distance': 32.31, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b7b'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 53.881, 'mass': 0.06472, 'distance': 32.31, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b7c'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1214.0, 'mass': 1.5, 'distance': 89.13, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671b7d'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 738.459, 'mass': 2.61, 'distance': 34.6, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671b7e'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 528.07, 'mass': 13.65, 'distance': 31.79, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b7f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1561.0, 'mass': 7.71, 'distance': 51.97, 'year': 2003}
# {'_id': ObjectId('63ece988ca290a73c9671b80'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 3668.0, 'mass': 4.01, 'distance': 46.51, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671b81'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1845.0, 'mass': 0.95, 'distance': 56.05, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b82'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 423.841, 'mass': 1.28, 'distance': 18.24, 'year': 2000}
# {'_id': ObjectId('63ece988ca290a73c9671b83'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2208.0, 'mass': 1.45, 'distance': 44.54, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671b84'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 17.991, 'mass': 0.62, 'distance': 42.37, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b85'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1117.0, 'mass': 1.16, 'distance': 56.18, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b86'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 385.9, 'mass': 5.59, 'distance': 39.56, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671b87'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 387.1, 'mass': 1.7, 'distance': 168.92, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b88'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2819.654, 'mass': 9.17, 'distance': 54.71, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b89'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1159.2, 'mass': 1.373, 'distance': 26.5, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b8a'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 912.0, 'mass': 1.8, 'distance': 121.07, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b8b'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 466.0, 'mass': 0.5, 'distance': 53.82, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b8c'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 16.546, 'mass': 0.0363, 'distance': 38.01, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b8d'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 51.284, 'mass': 0.0498, 'distance': 38.01, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b8e'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 274.49, 'mass': 0.0519, 'distance': 38.01, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b8f'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 326.6, 'mass': 1.3, 'distance': 136.8, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671b90'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 18.179, 'mass': 0.33, 'distance': 86.88, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671b91'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 157.54, 'mass': 3.04, 'distance': 117.37, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b92'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 1049.0, 'mass': 0.79, 'distance': 45.01, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671b93'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 388.0, 'mass': 9.1, 'distance': 20.98, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b94'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 363.2, 'mass': nan, 'distance': 37.78, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671b95'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 154.46, 'mass': 0.61, 'distance': 33.24, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b96'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 2295.0, 'mass': 0.683, 'distance': 33.24, 'year': 2002}
# {'_id': ObjectId('63ece988ca290a73c9671b97'), 'method': 'Radial Velocity', 'number': 3, 'orbital_period': 843.6, 'mass': 0.624, 'distance': 33.24, 'year': 2005}
# {'_id': ObjectId('63ece988ca290a73c9671b98'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2063.818, 'mass': 10.35, 'distance': 18.21, 'year': 2001}
# {'_id': ObjectId('63ece988ca290a73c9671b99'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 55.0, 'mass': 2.3, 'distance': 42.88, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671b9a'), 'method': 'Radial Velocity', 'number': 2, 'orbital_period': 2720.0, 'mass': 3.366, 'distance': 42.88, 'year': 2012}
# ...
# {'_id': ObjectId('63ece988ca290a73c9671e11'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.0161, 'mass': nan, 'distance': nan, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671e12'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.4324752, 'mass': nan, 'distance': 600.0, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671e13'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.689868, 'mass': nan, 'distance': 2500.0, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671e14'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.9791, 'mass': nan, 'distance': nan, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e15'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.67724, 'mass': nan, 'distance': nan, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e16'), 'method': 'Imaging', 'number': 1, 'orbital_period': 730000.0, 'mass': nan, 'distance': nan, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671e17'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.1606296, 'mass': nan, 'distance': 1200.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671e18'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 4.4264, 'mass': nan, 'distance': nan, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e19'), 'method': 'Radial Velocity', 'number': 1, 'orbital_period': 2.1451, 'mass': nan, 'distance': nan, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e1a'), 'method': 'Pulsar Timing', 'number': 3, 'orbital_period': 25.262, 'mass': nan, 'distance': nan, 'year': 1992}
# {'_id': ObjectId('63ece988ca290a73c9671e1b'), 'method': 'Pulsar Timing', 'number': 3, 'orbital_period': 66.5419, 'mass': nan, 'distance': nan, 'year': 1992}
# {'_id': ObjectId('63ece988ca290a73c9671e1c'), 'method': 'Pulsar Timing', 'number': 3, 'orbital_period': 98.2114, 'mass': nan, 'distance': nan, 'year': 1994}
# {'_id': ObjectId('63ece988ca290a73c9671e1d'), 'method': 'Pulsar Timing', 'number': 1, 'orbital_period': 36525.0, 'mass': nan, 'distance': nan, 'year': 2003}
# {'_id': ObjectId('63ece988ca290a73c9671e1e'), 'method': 'Pulsar Timing', 'number': 1, 'orbital_period': 0.09070629, 'mass': nan, 'distance': 1200.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e1f'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.420033, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e20'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.3371182, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e21'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 135.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671e22'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 120.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671e23'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e24'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.2, 'mass': nan, 'distance': 8500.0, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671e25'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.796, 'mass': nan, 'distance': 8500.0, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671e26'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.030065, 'mass': nan, 'distance': 152.3, 'year': 2004}
# {'_id': ObjectId('63ece988ca290a73c9671e27'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.30618581, 'mass': nan, 'distance': 228.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e28'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.553945, 'mass': nan, 'distance': 492.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e29'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.4822446, 'mass': nan, 'distance': 360.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e2a'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': nan, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e2b'), 'method': 'Pulsation Timing Variations', 'number': 1, 'orbital_period': 1170.0, 'mass': nan, 'distance': nan, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e2c'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.5199449, 'mass': nan, 'distance': 408.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e2d'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.152226, 'mass': nan, 'distance': 147.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e2e'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.846835, 'mass': nan, 'distance': 220.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e2f'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.33823187, 'mass': nan, 'distance': 300.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e30'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.62843142, 'mass': nan, 'distance': 300.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e31'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.361006, 'mass': nan, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e32'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.954658, 'mass': nan, 'distance': 140.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e33'), 'method': 'Transit', 'number': 1, 'orbital_period': 8.158715, 'mass': nan, 'distance': 87.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e34'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.0927616, 'mass': nan, 'distance': 90.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e35'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.7224747, 'mass': nan, 'distance': 121.7, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e36'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.091423, 'mass': nan, 'distance': nan, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e37'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.353011, 'mass': nan, 'distance': 155.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e38'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.243752, 'mass': nan, 'distance': 160.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e39'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.7520656, 'mass': nan, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e3a'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.1186009, 'mass': nan, 'distance': nan, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e3b'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.7354417, 'mass': nan, 'distance': 400.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e3c'), 'method': 'Transit', 'number': 1, 'orbital_period': 0.94145299, 'mass': nan, 'distance': 105.49, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e3d'), 'method': 'Transit', 'number': 1, 'orbital_period': 0.78884, 'mass': nan, 'distance': 250.0, 'year': 2009}
# {'_id': ObjectId('63ece988ca290a73c9671e3e'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.322482, 'mass': nan, 'distance': 242.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e3f'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.5327313, 'mass': nan, 'distance': 300.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e40'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.9444256, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e41'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.34121242, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e42'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.764825, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e43'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.7566004, 'mass': nan, 'distance': 250.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e44'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.408821, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e45'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.922727, 'mass': nan, 'distance': 70.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e46'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.4059096, 'mass': nan, 'distance': 360.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e47'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.718659, 'mass': nan, 'distance': nan, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e48'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.2198669, 'mass': nan, 'distance': 116.14, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e49'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.3176782, 'mass': nan, 'distance': 120.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e4a'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.161575, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e4b'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.5373653, 'mass': nan, 'distance': 450.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e4c'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.577469, 'mass': nan, 'distance': 343.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e4d'), 'method': 'Transit', 'number': 1, 'orbital_period': 6.871815, 'mass': nan, 'distance': 110.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e4e'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.055259, 'mass': nan, 'distance': 230.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e4f'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.052401, 'mass': nan, 'distance': 180.0, 'year': 2010}
# {'_id': ObjectId('63ece988ca290a73c9671e50'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.9816872, 'mass': nan, 'distance': 160.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e51'), 'method': 'Transit', 'number': 1, 'orbital_period': 0.813475, 'mass': nan, 'distance': 80.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e52'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.4238039, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e53'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.1260876, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e54'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.43037, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e55'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.1591399, 'mass': nan, 'distance': 200.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e56'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.143634, 'mass': nan, 'distance': nan, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e57'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.7817387, 'mass': nan, 'distance': 170.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e58'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.9550959, 'mass': nan, 'distance': 230.0, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e59'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.7497798, 'mass': nan, 'distance': 140.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e5a'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.6936411, 'mass': nan, 'distance': 200.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e5b'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.465633, 'mass': nan, 'distance': 330.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e5c'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.617101, 'mass': nan, 'distance': 255.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e5d'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.838971, 'mass': nan, 'distance': 455.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e5e'), 'method': 'Transit', 'number': 1, 'orbital_period': 5.01718, 'mass': nan, 'distance': 300.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e5f'), 'method': 'Transit', 'number': 1, 'orbital_period': 7.919585, 'mass': nan, 'distance': 125.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e60'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.3050011, 'mass': nan, 'distance': 400.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e61'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.8559, 'mass': nan, 'distance': 480.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e62'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.411953, 'mass': nan, 'distance': 160.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e63'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.37809, 'mass': nan, 'distance': 330.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e64'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.5732918, 'mass': nan, 'distance': 350.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e65'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.3114243, 'mass': nan, 'distance': 310.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671e66'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.086052, 'mass': nan, 'distance': 380.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e67'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.61442, 'mass': nan, 'distance': 225.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e68'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.9036747, 'mass': nan, 'distance': 345.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e69'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.2167421, 'mass': nan, 'distance': 340.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e6a'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.484193, 'mass': nan, 'distance': 260.0, 'year': 2013}
# {'_id': ObjectId('63ece988ca290a73c9671e6b'), 'method': 'Transit', 'number': 1, 'orbital_period': 1.3600309, 'mass': nan, 'distance': 93.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e6c'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.17517632, 'mass': nan, 'distance': 550.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e6d'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.6623866, 'mass': nan, 'distance': 240.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e6e'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.0678504, 'mass': nan, 'distance': 60.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e6f'), 'method': 'Transit', 'number': 1, 'orbital_period': 0.925542, 'mass': nan, 'distance': 470.0, 'year': 2014}
# {'_id': ObjectId('63ece988ca290a73c9671e70'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 19.2, 'year': 2011}
# {'_id': ObjectId('63ece988ca290a73c9671e71'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.352057, 'mass': nan, 'distance': 3200.0, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e72'), 'method': 'Imaging', 'number': 1, 'orbital_period': nan, 'mass': nan, 'distance': 10.1, 'year': 2012}
# {'_id': ObjectId('63ece988ca290a73c9671e73'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.94150685, 'mass': nan, 'distance': 172.0, 'year': 2006}
# {'_id': ObjectId('63ece988ca290a73c9671e74'), 'method': 'Transit', 'number': 1, 'orbital_period': 2.615864, 'mass': nan, 'distance': 148.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e75'), 'method': 'Transit', 'number': 1, 'orbital_period': 3.1915239, 'mass': nan, 'distance': 174.0, 'year': 2007}
# {'_id': ObjectId('63ece988ca290a73c9671e76'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.1250828, 'mass': nan, 'distance': 293.0, 'year': 2008}
# {'_id': ObjectId('63ece988ca290a73c9671e77'), 'method': 'Transit', 'number': 1, 'orbital_period': 4.187757, 'mass': nan, 'distance': 260.0, 'year': 2008}

# %%
df = sns.load_dataset('taxis')

# %%
db = client["taxis"]

# %%
collection = db["records"]

# %%
data = df.to_dict(orient="record")
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_20340\4910782.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data = df.to_dict(orient="record")

# %%
collection.insert_many(data)
