# %%
from pprint import pprint
import pandas as pd
import seaborn as sns
import pymongo
client = pymongo.MongoClient("mongodb+srv://yashmohite:12345678ym@cluster0.urvqe3y.mongodb.net/?retryWrites=true&w=majority")
db = client.test #pointer
print(db)
# Out:
# Database(MongoClient(host=['ac-d6qyvfk-shard-00-00.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-01.urvqe3y.mongodb.net:27017', 'ac-d6qyvfk-shard-00-02.urvqe3y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lkhn33-shard-0', tls=True), 'test')

# %%
db = client["code_with_harry"]

# %%
collection = db["records"]

# %%
data = pd.read_csv("code_with_harry.csv")

# %%
data = data.to_dict(orient="record")
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_2224\2704615251.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data = data.to_dict(orient="record")

# %%
collection.insert_many(data)

# %%
for i in collection.find():
    pprint(i)
# Out:
# {'_id': ObjectId('63ef58b21c8a1749141e4a2b'),
#  'discription': 'FREE COURSEPython Tutorials - 100 Days of CodePython is one '
#                 'of the most demanded programming languages in the job market. '
#                 'Surprisingly, it is equally easy to learn and master Python. '
#                 "Let's commit our 100 days of code to python!  Start Watching ",
#  'gears': 'Canon EOS 80D',
#  'gears_discription': 'This is what I use to create my content. I am not '
#                       'sponsored by any of these companies.',
#  'overview': 'Python is one of the most demanded programming languages in the '
#              'job market. Surprisingly, it is equally easy to learn and master '
#              "Python. Let's commit our 100 days of code to python!",
#  'titles': 'Python Tutorials - 100 Days of Code'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a2c'),
#  'discription': 'FREE COURSEUltimate JavaScript CourseThis latest JavaScript '
#                 'course comes with premium curriculum that covers everything '
#                 'from basics to advance. On top of that, you will get my '
#                 'handwritten notes of JS for completely free. What are you '
#                 'waiting for? Just Enroll Buddy  Start Watching ',
#  'gears': 'iPhone 13 Pro Max 256GB',
#  'gears_discription': ' I bought it back in 2018 for my US trip and have been '
#                       'using it since then. If you want to buy this in 2022, '
#                       'go for the EOS 90D (Same camera - Updated version). '
#                       'This is an amazing camera given that its still working '
#                       'exactly like it was working when I bought it. I use it '
#                       'for my YouTube tutorial videos as well. I use a USB '
#                       'cable, EOS utility software to make videos.',
#  'overview': 'This latest JavaScript course comes with premium curriculum that '
#              'covers everything from basics to advance. On top of that, you '
#              'will get my handwritten notes of JS for completely free. What '
#              'are you waiting for? Just Enroll Buddy',
#  'titles': 'Ultimate JavaScript Course'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a2d'),
#  'discription': 'FREE COURSETailwind Course In HindiComplete Tailwind CSS '
#                 'Course by CodeWithHarry in Hindi - Learn Tailwind CSS from '
#                 'scratch for free!   Start Watching ',
#  'gears': 'Lenovo 300 FHD Webcam',
#  'gears_discription': ' I have always dreamt of buying an iPhone for myself. '
#                       'Back in 2021, I finally bought my first ever iPhone and '
#                       'its been a great phone so far. I use it for my YouTube '
#                       'videos and also for my Instagram stories. I also use it '
#                       'to take photos for my YouTube thumbnails.',
#  'overview': 'Complete Tailwind CSS Course by CodeWithHarry in Hindi - Learn '
#              'Tailwind CSS from scratch for free! ',
#  'titles': 'Tailwind Course In Hindi'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a2e'),
#  'discription': 'FREE COURSESanity.io Tutorials in HindiSanity.io is the '
#                 'platform for structured content. This course will not only '
#                 'cover Sanity from starting to the end, but it has projects '
#                 'for hands-on experience.  Start Watching ',
#  'gears': 'Blue Yeti',
#  'gears_discription': ' Sometimes I also use this Webcam to record videos. '
#                       'This has a great camera, and the microphone on this '
#                       'device is also good. This is a good webcam at its '
#                       'price.',
#  'overview': 'Sanity.io is the platform for structured content. This course '
#              'will not only cover Sanity from starting to the end, but it has '
#              'projects for hands-on experience.',
#  'titles': 'Sanity.io Tutorials in Hindi'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a2f'),
#  'discription': 'FREE COURSEStrapi Tutorial For BeginnersThis course contains '
#                 'everything that you should know about Strapi. It is an '
#                 'open-source, Headless CMS that saves lot of time for '
#                 'developers by giving them freedom to use their favorite tools '
#                 'and frameworks.  Start Watching ',
#  'gears': 'Blue Snowball ICE',
#  'gears_discription': ' This is my main microphone, and I got this back in '
#                       '2021. Before this, I used Snowball ICE to record the '
#                       'videos, but I wanted to upgrade, so I bought this '
#                       'microphone. I have used it for all of my videos since '
#                       'then. This microphone has a crisp audio quality and '
#                       'good noise suppression.',
#  'overview': 'This course contains everything that you should know about '
#              'Strapi. It is an open-source, Headless CMS that saves lot of '
#              'time for developers by giving them freedom to use their favorite '
#              'tools and frameworks.',
#  'titles': 'Strapi Tutorial For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a30'),
#  'discription': 'FREE COURSEReact Js Tutorials For BeginnersReact is a free '
#                 'and open-source front-end JavaScript library. This series '
#                 'will cover React from starting to the end. We will learn '
#                 'react from the ground up!  Start Watching ',
#  'gears': 'Boya BY-M1',
#  'gears_discription': ' This is my secondary microphone and I got this back in '
#                       '2016 when I started YouTube. I used it for all of my '
#                       'videos back then. This has a crisp audio quality and '
#                       'good noise suppression. I still use this Microphone.',
#  'overview': 'React is a free and open-source front-end JavaScript library. '
#              'This series will cover React from starting to the end. We will '
#              'learn react from the ground up!',
#  'titles': 'React Js Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a31'),
#  'discription': 'FREE COURSENext.js Tutorials For BeginnersComplete Next.js '
#                 'Course by CodeWithHarry in Hindi - Learn Next.js from '
#                 'Scratch.  Start Watching ',
#  'gears': 'Rode SmartLav+',
#  'gears_discription': ' This is another mic I use for my videos. I got this '
#                       'when I was a little tight on my budget. This microphone '
#                       'is what I can say is value for money. This has good '
#                       'audio quality and its easy to setup. But soon I stopped '
#                       'using it and upgraded due to its limited battery '
#                       'backup.',
#  'overview': 'Complete Next.js Course by CodeWithHarry in Hindi - Learn '
#              'Next.js from Scratch.',
#  'titles': 'Next.js Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a32'),
#  'discription': 'FREE COURSEGeneral Python ErrorsBeing a coder, I can '
#                 'understand the pain and excitement while finding a bug or '
#                 'error in a code. This course contains some of the most famous '
#                 'or common errors in the Python language.  Start Watching ',
#  'gears': 'Apple iPad Pro with Apple M1 chip 2021',
#  'gears_discription': ' It is a good lavalier condenser microphone, but it is '
#                       'a bit costly. I bought it as an upgrade to my Boya '
#                       'BY-M1. It is easy to setup, and sometimes I use it with '
#                       'my iPhone to record audio.',
#  'overview': 'Being a coder, I can understand the pain and excitement while '
#              'finding a bug or error in a code. This course contains some of '
#              'the most famous or common errors in the Python language.',
#  'titles': 'General Python Errors'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a33'),
#  'discription': 'FREE COURSEC Language Practice ProgramsThis series contains '
#                 'programs for you to practice C Programming and related '
#                 'concepts. It has videos that will provide you with a proper '
#                 'explanation of the program and its logic.  Start Watching ',
#  'gears': '2021 Apple MacBook Pro (14-inch)',
#  'gears_discription': ' I got this back on 2021. I bought it for taking notes '
#                       'and making videos. It is a good product altogether but '
#                       "I haven't used it much.",
#  'overview': 'This series contains programs for you to practice C Programming '
#              'and related concepts. It has videos that will provide you with a '
#              'proper explanation of the program and its logic.',
#  'titles': 'C Language Practice Programs'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a34'),
#  'discription': "FREE COURSEPython Game Development TutsIf you're interested "
#                 'in game development, this course is for you. It will lead you '
#                 'through all the basic game development concepts and will give '
#                 'you an initial boost.  Start Watching ',
#  'gears': 'ASUS ROG Strix G17 (2021)',
#  'gears_discription': ' I purchased this in 2022 and this has been my primary '
#                       'laptop since then. Being a content creator this is one '
#                       'of my best decisions and, long story short, this laptop '
#                       'has never disappointed me.',
#  'overview': "If you're interested in game development, this course is for "
#              'you. It will lead you through all the basic game development '
#              'concepts and will give you an initial boost.',
#  'titles': 'Python Game Development Tuts'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a35'),
#  'discription': "FREE COURSEOOPS Using Python ProgrammingIf you don't know "
#                 'about Object Oriented Programming (OOP) Paradigm, then this '
#                 "course is for you. In this you'll learn about objects, "
#                 'classes and much more in Python language.  Start Watching ',
#  'gears': 'Intel Core i9-10900K',
#  'gears_discription': ' I purchased this in 2021 and this has been my primary '
#                       'laptop since then. I upgraded its RAM to 64GB (being a '
#                       'content creator) and, long story short, this laptop has '
#                       'never disappointed me.',
#  'overview': "If you don't know about Object Oriented Programming (OOP) "
#              "Paradigm, then this course is for you. In this you'll learn "
#              'about objects, classes and much more in Python language.',
#  'titles': 'OOPS Using Python Programming'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a36'),
#  'discription': 'FREE COURSEBasic Python Programs With CodeThis series '
#                 "contains basic Python programs. It's a concise and precise "
#                 'course, so if you have a couple of minutes or an hour, just '
#                 'get started. This course will surely add some value.  Start '
#                 'Watching ',
#  'gears': 'Nvidia GeForce RTX 3070 8GB',
#  'gears_discription': ' This is my main CPU. This beast is packed with 10 '
#                       'cores and 20 threads. It is a great CPU for those who '
#                       'want to do 4K encoding and video editing. I bought it '
#                       'in 2021 and it is still going strong.',
#  'overview': "This series contains basic Python programs. It's a concise and "
#              'precise course, so if you have a couple of minutes or an hour, '
#              'just get started. This course will surely add some value.',
#  'titles': 'Basic Python Programs With Code'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a37'),
#  'discription': 'FREE COURSEWeb Dev Using Flask and PythonThis course will '
#                 'teach you everything you need to know about web development '
#                 'using Flask. It will lead you through each and every concept '
#                 'of Flask and will give you a good initial start.  Start '
#                 'Watching ',
#  'gears': 'XPG Adata GAMMIX D30 64GB (4x16GB)',
#  'gears_discription': ' This is my GPU. This beast is packed with 8GB of VRAM. '
#                       'I literally had to wait for 2 months to get this GPU '
#                       'back in 2021, when the GPU crisis was at its peak. I '
#                       'have no complaints regarding this GPU. It delivers what '
#                       'it promises.',
#  'overview': 'This course will teach you everything you need to know about web '
#              'development using Flask. It will lead you through each and every '
#              'concept of Flask and will give you a good initial start.',
#  'titles': 'Web Dev Using Flask and Python'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a38'),
#  'discription': 'FREE COURSECoding Discussion With HarryInterested in general '
#                 'technology (coding) topics? If yes, then you must checkout '
#                 "this series, here you'll get tonnes of videos regarding most "
#                 'asked questions and other general questions.  Start Watching ',
#  'gears': 'MSI MPG Z490 Gaming Plus Motherboard',
#  'gears_discription': ' This is my RAM. At first I had only 32GB of RAM, but '
#                       'then I upgraded it to 64GB. This RAM runs at 3600MHz, '
#                       'and it is a great RAM in terms of performance.',
#  'overview': 'Interested in general technology (coding) topics? If yes, then '
#              "you must checkout this series, here you'll get tonnes of videos "
#              'regarding most asked questions and other general questions.',
#  'titles': 'Coding Discussion With Harry'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a39'),
#  'discription': "FREE COURSELearn In One VideoDon't have much time to watch "
#                 "the whole course's playlist? Don't worry, we've got you "
#                 'covered. This series contains one-shot videos of popular '
#                 "technologies, search for your required stack, and you're "
#                 'ready to get into it.  Start Watching ',
#  'gears': 'Antec HCG850 Power Supply',
#  'gears_discription': ' This is my motherboard. I bought it for my Beast PC '
#                       'build and it is still going strong. This motherboard '
#                       'has lots of USB ports and, on top of that, it has 2 M.2 '
#                       'NVME slots, which is great for those who want to '
#                       'install 2 SSDs.',
#  'overview': "Don't have much time to watch the whole course's playlist? Don't "
#              "worry, we've got you covered. This series contains one-shot "
#              'videos of popular technologies, search for your required stack, '
#              "and you're ready to get into it.",
#  'titles': 'Learn In One Video'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a3a'),
#  'discription': 'FREE COURSEC++ Tutorials For BeginnersThis course contains '
#                 "all the concepts and exercises of the C++ language. If you're "
#                 'a mere beginner, you can start your coding journey with this '
#                 'course and ace your exams.  Start Watching ',
#  'gears': 'Western Digital WD SN550 1TB NVMe SSD',
#  'gears_discription': ' This is my main power supply. This is packed with 850W '
#                       'of power and it is 80 Plus Gold certified. This is a '
#                       'fully modular PSU with a 135mm fan. This power supply '
#                       'is great for those who want to build a high-end PC.',
#  'overview': 'This course contains all the concepts and exercises of the C++ '
#              "language. If you're a mere beginner, you can start your coding "
#              'journey with this course and ace your exams.',
#  'titles': 'C++ Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a3b'),
#  'discription': 'FREE COURSEPython Django Tutorials For BeginnersDjango is a '
#                 'Python-based free and open-source web framework. If you '
#                 'already know Python and want to try web development, you can '
#                 'go with Django.  Start Watching ',
#  'gears': 'Montech X1 White Case',
#  'gears_discription': ' This is my main Storage. This is one of the best SSDs '
#                       "out there. It's value for money, and also this SSD is "
#                       "blazing fast in terms of performance. I'm a gaming "
#                       'person and a programmer and I can say for sure that '
#                       'this SSD never disappoints.',
#  'overview': 'Django is a Python-based free and open-source web framework. If '
#              'you already know Python and want to try web development, you can '
#              'go with Django.',
#  'titles': 'Python Django Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a3c'),
#  'discription': 'FREE COURSEWeb Dev Tutorials For BeginnersThis is one of my '
#                 "favorite courses. In this series, you'll learn about HTML, "
#                 'CSS, JavaScript, and everything needed to be a job-ready web '
#                 'developer. Just hop on, man.  Start Watching ',
#  'gears': 'Cooler Master MasterLiquid ML360L ARGB V2',
#  'gears_discription': ' In terms of the case, this is a great looking case. I '
#                       'purchased it for its good looks and good airflow too. '
#                       'This case is packed with 4 x 120mm fans. So far, it is '
#                       'a great case, and I dont have any complaints.',
#  'overview': "This is one of my favorite courses. In this series, you'll learn "
#              'about HTML, CSS, JavaScript, and everything needed to be a '
#              'job-ready web developer. Just hop on, man.',
#  'titles': 'Web Dev Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a3d'),
#  'discription': 'FREE COURSEPython Tutorials For Absolute BeginnersThis is one '
#                 'of the most-watched courses on this channel. If you want to '
#                 'create projects as early as possible, then this course is for '
#                 "you. You'll get dozen of projects in this course.  Start "
#                 'Watching ',
#  'gears': 'TVS Gold Keyboard',
#  'gears_discription': ' This is my CPU cooler. This comes with 360mm radiator. '
#                       'In terms of cooling, this is a beast. It keeps my CPU '
#                       "cool even when I'm playing games. This is a great CPU "
#                       'cooler and I would recommend it to anyone who want to '
#                       'build a high end PC.',
#  'overview': 'This is one of the most-watched courses on this channel. If you '
#              'want to create projects as early as possible, then this course '
#              "is for you. You'll get dozen of projects in this course.",
#  'titles': 'Python Tutorials For Absolute Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a3e'),
#  'discription': 'FREE COURSEAndroid Development TutorialsAndroid Development '
#                 'is one of the booming career options nowadays, and many '
#                 'people are learning Android because it feels so good to '
#                 'create own app. You can also grab this opportunity by '
#                 'enrolling in this course.  Start Watching ',
#  'gears': 'Zebronics Zeb-Transformer-M',
#  'gears_discription': ' This keyboard is a bit old. Honestly, I use it more '
#                       'because of emotions than anything else. You can buy any '
#                       'other mechanical keyboard, but I use it because I have '
#                       'been using the same one for a very long time.',
#  'overview': 'Android Development is one of the booming career options '
#              'nowadays, and many people are learning Android because it feels '
#              'so good to create own app. You can also grab this opportunity by '
#              'enrolling in this course.',
#  'titles': 'Android Development Tutorials'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a3f'),
#  'discription': "FREE COURSEJava Tutorials For BeginnersIf you don't know "
#                 'programming and want to start your career by learning Java as '
#                 'your first language, you can start with this course as it is '
#                 'for absolute beginners.  Start Watching ',
#  'gears': 'Western Digital WD 2TB Elements',
#  'gears_discription': ' This is a very nice affordable gaming mouse. At around '
#                       '349 INR, it is a lot of value for money!',
#  'overview': "If you don't know programming and want to start your career by "
#              'learning Java as your first language, you can start with this '
#              'course as it is for absolute beginners.',
#  'titles': 'Java Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a40'),
#  'discription': 'FREE COURSEData Structures and Algorithms CourseData '
#                 'Structure and Algorithm is one of the most crucial things to '
#                 'learn. This course will give you a complete understanding of '
#                 'Data Structure and its implementation.  Start Watching ',
#  'gears': 'Monarch Elevate Height Adjustable Table',
#  'gears_discription': ' My oldest storage device (Using it since 2018) which '
#                       'is still working and has not yet disappointed me!',
#  'overview': 'Data Structure and Algorithm is one of the most crucial things '
#              'to learn. This course will give you a complete understanding of '
#              'Data Structure and its implementation.',
#  'titles': 'Data Structures and Algorithms Course'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a41'),
#  'discription': 'FREE COURSEC Language Tutorials For BeginnersEven if you '
#                 "don't know the ABC of coding, start this course, and I can "
#                 "assure you that you'll be an intermediate-level coder after "
#                 'completion. Get started with C language.  Start Watching ',
#  'gears': 'Green Soul Beast Racing Edition Ergonomic Gaming Chair',
#  'gears_discription': ' When you are working for hours, it is recommended that '
#                       'you use a standing desk. I love switching between '
#                       'standing and sitting positions while I am working for '
#                       'long hours on my projects. Sitting for a long time is '
#                       'not good for your knees, for your spine, and for your '
#                       'overall posture too.',
#  'overview': "Even if you don't know the ABC of coding, start this course, and "
#              "I can assure you that you'll be an intermediate-level coder "
#              'after completion. Get started with C language.',
#  'titles': 'C Language Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a42'),
#  'discription': 'FREE COURSEJavaScript Tutorials For BeginnersJavaScript is an '
#                 'essential element for the web developers. If you want to take '
#                 'your web development journey one step ahead then you enroll '
#                 'in this course.  Start Watching ',
#  'gears': 'Green soul stool',
#  'gears_discription': ' Buying this was one of the best decisions. It feels '
#                       'amazing and very comfortable. If you can afford it you '
#                       'can go for it!',
#  'overview': 'JavaScript is an essential element for the web developers. If '
#              'you want to take your web development journey one step ahead '
#              'then you enroll in this course.',
#  'titles': 'JavaScript Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a43'),
#  'discription': 'FREE COURSEPHP Tutorials For BeginnersPHP is a '
#                 'general-purpose scripting language geared towards web '
#                 'development. This course will give you a complete and proper '
#                 'understanding of PHP concepts.  Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': 'PHP is a general-purpose scripting language geared towards web '
#              'development. This course will give you a complete and proper '
#              'understanding of PHP concepts.',
#  'titles': 'PHP Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a44'),
#  'discription': "FREE COURSEGit and GitHub Tutorials For BeginnersIf you're "
#                 'serious about coding and want to make a career out of it, '
#                 'then do learn Git and GitHub because it is something that '
#                 "you'll use at every phase of your job.  Start Watching ",
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': "If you're serious about coding and want to make a career out of "
#              'it, then do learn Git and GitHub because it is something that '
#              "you'll use at every phase of your job.",
#  'titles': 'Git and GitHub Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a45'),
#  'discription': 'FREE COURSEIntermediate Python TutorialsWanna take your '
#                 'Python skills to the next level? This course is what you all '
#                 'need. It contains all the advanced concepts of the Python '
#                 'language. What??? Just tap on the "Start Watching" button to '
#                 'get started.  Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': 'Wanna take your Python skills to the next level? This course is '
#              'what you all need. It contains all the advanced concepts of the '
#              'Python language. What??? Just tap on the "Start Watching" button '
#              'to get started.',
#  'titles': 'Intermediate Python Tutorials'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a46'),
#  'discription': 'FREE COURSEData Science and Big Data TutorialsThis course '
#                 "will give you a gist of Data Science and Big Data. I'm sure "
#                 'you must have heard about Data Scientist. This series '
#                 'contains the content to become one of them.  Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': 'This course will give you a gist of Data Science and Big Data. '
#              "I'm sure you must have heard about Data Scientist. This series "
#              'contains the content to become one of them.',
#  'titles': 'Data Science and Big Data Tutorials'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a47'),
#  'discription': 'FREE COURSEML Tutorials For BeginnersMachine Learning is one '
#                 'of the exciting topics nowadays. And if you want to get a '
#                 "glimpse of ML, don't think twice. Just get started with this "
#                 'course.  Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': 'Machine Learning is one of the exciting topics nowadays. And if '
#              "you want to get a glimpse of ML, don't think twice. Just get "
#              'started with this course.',
#  'titles': 'ML Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a48'),
#  'discription': "FREE COURSEComplete Git Tutorials For BeginnersIf you're "
#                 'serious about coding and want to make a career out of it, '
#                 'then do learn Git and GitHub. This is the updated course of '
#                 'Git and GitHub For Beginners.  Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': "If you're serious about coding and want to make a career out of "
#              'it, then do learn Git and GitHub. This is the updated course of '
#              'Git and GitHub For Beginners.',
#  'titles': 'Complete Git Tutorials For Beginners'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a49'),
#  'discription': 'FREE COURSEPython GUI Tkinter TutorialsConsole output is '
#                 "annoying sometimes, isn't it? That's why to get rid of the "
#                 'console, you can create GUI programs, and this is the course '
#                 'for you to start with. "Spill some colors in your program."  '
#                 'Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': "Console output is annoying sometimes, isn't it? That's why to "
#              'get rid of the console, you can create GUI programs, and this is '
#              'the course for you to start with. "Spill some colors in your '
#              'program."',
#  'titles': 'Python GUI Tkinter Tutorials'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a4a'),
#  'discription': 'FREE COURSEPython Practice Program TutsThis series contains '
#                 'some of the exciting Python programs that one must try. '
#                 "You'll also get a proper explanation of the code. So, get "
#                 'started with this course to practice Python.  Start Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': 'This series contains some of the exciting Python programs that '
#              "one must try. You'll also get a proper explanation of the code. "
#              'So, get started with this course to practice Python.',
#  'titles': 'Python Practice Program Tuts'}
# {'_id': ObjectId('63ef58b21c8a1749141e4a4b'),
#  'discription': 'FREE COURSERealtime PHP Chatroom TutorialsThis is one of the '
#                 "best applications of PHP and Jquery. In this series, we've "
#                 "developed a real-time chatroom, so if you're someone who "
#                 'likes project-based learning, this is for you.  Start '
#                 'Watching ',
#  'gears': nan,
#  'gears_discription': nan,
#  'overview': 'This is one of the best applications of PHP and Jquery. In this '
#              "series, we've developed a real-time chatroom, so if you're "
#              'someone who likes project-based learning, this is for you.',
#  'titles': 'Realtime PHP Chatroom Tutorials'}
